# %% [markdown]
# ## 导入Python库

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import gc
from collections import Counter
import copy

import warnings
warnings.filterwarnings("ignore")
 
# %matplotlib inline

# %% [markdown]
# ## 数据读取

# %%
# #读取数据集
#
# test_data = pd.read_csv('./data_format1/test_format1.csv')
# train_data = pd.read_csv('./data_format1/train_format1.csv')
#
# user_info = pd.read_csv('./data_format1/user_info_format1.csv')
# user_log = pd.read_csv('./data_format1/user_log_format1.csv')

# %% [markdown]
# ## 查看数据

# %%
# train_data.info()
#

# %%
# test_data.info()
#

# %%
# user_info.info()
#

# %%
# user_log.info()

# %% [markdown]
# ## 数据读取函数

# %%
def read_csv(file_name, num_rows):
    return pd.read_csv(file_name, nrows=num_rows)

# %% [markdown]
# ## 内存压缩方法

# %%
# reduce memory
def reduce_mem_usage(df, verbose=True):
    start_mem = df.memory_usage().sum() / 1024**2
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
                    
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    return df

# %% [markdown]
# ## 数据进行内存压缩

# %%
num_rows = None
#num_rows = 2000  # 1000条测试代码使用

train_file = './data_format1/train_format1.csv'
test_file = './data_format1/test_format1.csv'

user_info_file = './data_format1/user_info_format1.csv'
user_log_file = './data_format1/user_log_format1.csv'

train_data = reduce_mem_usage(read_csv(train_file, num_rows))
test_data = reduce_mem_usage(read_csv(test_file, num_rows))

user_info = reduce_mem_usage(read_csv(user_info_file, num_rows))
user_log = reduce_mem_usage(read_csv(user_log_file, num_rows))
# Out:
# Memory usage after optimization is: 1.74 MB
# Decreased by 70.8%
# Memory usage after optimization is: 3.49 MB
# Decreased by 41.7%
# Memory usage after optimization is: 3.24 MB
# Decreased by 66.7%
# Memory usage after optimization is: 890.48 MB
# Decreased by 69.6%

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260864 entries, 0 to 260863
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   user_id      260864 non-null  int32
#  1   merchant_id  260864 non-null  int16
#  2   label        260864 non-null  int8
# dtypes: int16(1), int32(1), int8(1)
# memory usage: 1.7 MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261477 entries, 0 to 261476
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   user_id      261477 non-null  int32
#  1   merchant_id  261477 non-null  int16
#  2   prob         0 non-null       float64
# dtypes: float64(1), int16(1), int32(1)
# memory usage: 3.5 MB

# %%
user_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424170 entries, 0 to 424169
# Data columns (total 3 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    424170 non-null  int32
#  1   age_range  421953 non-null  float16
#  2   gender     417734 non-null  float16
# dtypes: float16(2), int32(1)
# memory usage: 3.2 MB

# %%
user_log.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54925330 entries, 0 to 54925329
# Data columns (total 7 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   user_id      int32
#  1   item_id      int32
#  2   cat_id       int16
#  3   seller_id    int16
#  4   brand_id     float16
#  5   time_stamp   int16
#  6   action_type  int8
# dtypes: float16(1), int16(3), int32(2), int8(1)
# memory usage: 890.5 MB

# %% [markdown]
# ## 数据处理
#
# ### 合并用户信息

# %%
all_data = train_data.append(test_data)
all_data = all_data.merge(user_info,on=['user_id'],how='left')
del train_data, test_data, user_info
gc.collect()
# Out:
# 239

# %% [markdown]
# ### 用户行为日志信息按时间进行排序

# %%
"""
按时间排序
"""
user_log = user_log.sort_values(['user_id','time_stamp'])

# %% [markdown]
# ### 对每个用户的逐个合并所有的item_id, cat_id,seller_id,brand_id,time_stamp, action_type字段

# %%
"""
合并数据
"""
list_join_func = lambda x: " ".join([str(i) for i in x])


agg_dict = {
            'item_id' : list_join_func,	
            'cat_id' : list_join_func,
            'seller_id' : list_join_func,
            'brand_id' : list_join_func,
            'time_stamp' : list_join_func,
            'action_type' : list_join_func
        }

rename_dict = {
            'item_id' : 'item_path',
            'cat_id' : 'cat_path',
            'seller_id' : 'seller_path',
            'brand_id' : 'brand_path',
            'time_stamp' : 'time_stamp_path',
            'action_type' : 'action_type_path'
        }

def merge_list(df_ID, join_columns, df_data, agg_dict, rename_dict):
    df_data = df_data.\
            groupby(join_columns).\
            agg(agg_dict).\
            reset_index().\
            rename(columns=rename_dict)

    df_ID = df_ID.merge(df_data, on=join_columns, how="left")
    return df_ID

all_data = merge_list(all_data, 'user_id', user_log, agg_dict, rename_dict)

# %% [markdown]
# ### 删除数据并回收内存

# %%
"""
删除不需要的数据
"""
del user_log
gc.collect()
# Out:
# 140

# %% [markdown]
# ## 定义数据统计函数
#
# ### 统计数据的总数

# %%
def cnt_(x):
    try:
        return len(x.split(' '))
    except:
        return -1

# %% [markdown]
# ### 统计唯一数据总数

# %%
def nunique_(x):
    try:
        return len(set(x.split(' ')))
    except:
        return -1

# %% [markdown]
# ### 统计数据最大值

# %%
def max_(x):
    try:
        return np.max([int(i) for i in x.split(' ')])
    except:
        return -1

# %% [markdown]
# ### 统计数据最小值

# %%
def min_(x):
    try:
        return np.min([int(i) for i in x.split(' ')])
    except:
        return -1

# %% [markdown]
# ### 统计数据的标准差

# %%
def std_(x):
    try:
        return np.std([float(i) for i in x.split(' ')])
    except:
        return -1

# %% [markdown]
# ### 统计数据中top N的数据

# %%
def most_n(x, n):
    try:
        return Counter(x.split(' ')).most_common(n)[n-1][0]
    except:
        return -1

# %% [markdown]
# ### 统计数据中top N数据的总数

# %%
def most_n_cnt(x, n):
    try:
        return Counter(x.split(' ')).most_common(n)[n-1][1]
    except:
        return -1

# %%
###
def user_cnt(df_data, single_col, name):
    df_data[name] = df_data[single_col].apply(cnt_)
    return df_data

def user_nunique(df_data, single_col, name):
    df_data[name] = df_data[single_col].apply(nunique_)
    return df_data
    
def user_max(df_data, single_col, name):
    df_data[name] = df_data[single_col].apply(max_)
    return df_data

def user_min(df_data, single_col, name):
    df_data[name] = df_data[single_col].apply(min_)
    return df_data
    
def user_std(df_data, single_col, name):
    df_data[name] = df_data[single_col].apply(std_)
    return df_data

def user_most_n(df_data, single_col, name, n=1):
    func = lambda x: most_n(x, n)
    df_data[name] = df_data[single_col].apply(func)
    return df_data

def user_most_n_cnt(df_data, single_col, name, n=1):
    func = lambda x: most_n_cnt(x, n)
    df_data[name] = df_data[single_col].apply(func)
    return df_data

# %% [markdown]
# ### 提取商铺的基本统计特征

# %%
"""
	提取基本统计特征
"""
# all_data_test = all_data.head(2000)
all_data_test = all_data
# 统计用户 点击、浏览、加购、购买行为
# 总次数
all_data_test = user_cnt(all_data_test,  'seller_path', 'user_cnt')
# 不同店铺个数
all_data_test = user_nunique(all_data_test,  'seller_path', 'seller_nunique')
# 不同品类个数
all_data_test = user_nunique(all_data_test,  'cat_path', 'cat_nunique')
# 不同品牌个数
all_data_test = user_nunique(all_data_test,  'brand_path', 'brand_nunique')
# 不同商品个数
all_data_test = user_nunique(all_data_test,  'item_path', 'item_nunique')
# 活跃天数
all_data_test = user_nunique(all_data_test,  'time_stamp_path', 'time_stamp_nunique')
# 不用行为种数
all_data_test = user_nunique(all_data_test,  'action_type_path', 'action_type_nunique')

# %%
# 最晚时间
all_data_test = user_max(all_data_test,  'action_type_path', 'time_stamp_max')
# 最早时间
all_data_test = user_min(all_data_test,  'action_type_path', 'time_stamp_min')
# 活跃天数方差
all_data_test = user_std(all_data_test,  'action_type_path', 'time_stamp_std')
# 最早和最晚相差天数
all_data_test['time_stamp_range'] = all_data_test['time_stamp_max'] - all_data_test['time_stamp_min']

# %%
# 用户最喜欢的店铺
all_data_test = user_most_n(all_data_test, 'seller_path', 'seller_most_1', n=1)
# 最喜欢的类目
all_data_test = user_most_n(all_data_test, 'cat_path', 'cat_most_1', n=1)
# 最喜欢的品牌
all_data_test = user_most_n(all_data_test, 'brand_path', 'brand_most_1', n=1)
# 最常见的行为动作
all_data_test = user_most_n(all_data_test, 'action_type_path', 'action_type_1', n=1)
# .....

# %%
# 用户最喜欢的店铺 行为次数
all_data_test = user_most_n_cnt(all_data_test, 'seller_path', 'seller_most_1_cnt', n=1)
# 最喜欢的类目 行为次数
all_data_test = user_most_n_cnt(all_data_test, 'cat_path', 'cat_most_1_cnt', n=1)
# 最喜欢的品牌 行为次数
all_data_test = user_most_n_cnt(all_data_test, 'brand_path', 'brand_most_1_cnt', n=1)
# 最常见的行为动作 行为次数
all_data_test = user_most_n_cnt(all_data_test, 'action_type_path', 'action_type_1_cnt', n=1)
# .....

# %% [markdown]
# ## 分开统计用户的点击，加购，购买，收藏特征
#
# ### 不同行为的业务函数定义

# %%
# 点击、加购、购买、收藏 分开统计
"""
统计基本特征函数  
-- 知识点二
-- 根据不同行为的业务函数
-- 提取不同特征
"""
def col_cnt_(df_data, columns_list, action_type):
	try:
	    data_dict = {}
	    
	    col_list = copy.deepcopy(columns_list)
	    if action_type != None:
	        col_list += ['action_type_path']

	    for col in col_list:
	        data_dict[col] = df_data[col].split(' ')

	    path_len = len(data_dict[col])
	    
	    data_out = []
	    for i_ in range(path_len):
	        data_txt = ''
	        for col_ in columns_list:
	            if data_dict['action_type_path'][i_] == action_type:
	                data_txt += '_' + data_dict[col_][i_]
	        data_out.append(data_txt)
	    
	    return len(data_out)  
	except:
		return -1

def col_nuique_(df_data, columns_list, action_type):
	try:
	    data_dict = {}
	    
	    col_list = copy.deepcopy(columns_list)
	    if action_type != None:
	        col_list += ['action_type_path']

	    for col in col_list:
	        data_dict[col] = df_data[col].split(' ')

	    path_len = len(data_dict[col])
	    
	    data_out = []
	    for i_ in range(path_len):
	        data_txt = ''
	        for col_ in columns_list:
	            if data_dict['action_type_path'][i_] == action_type:
	                data_txt += '_' + data_dict[col_][i_]
	        data_out.append(data_txt)

	    return len(set(data_out))
	except:
		return -1
    

def user_col_cnt(df_data, columns_list, action_type, name):
    df_data[name] = df_data.apply(lambda x: col_cnt_(x, columns_list, action_type), axis=1)
    return df_data

def user_col_nunique(df_data, columns_list, action_type, name):
    df_data[name] = df_data.apply(lambda x: col_nuique_(x, columns_list, action_type), axis=1)
    return df_data

# %% [markdown]
# ### 统计店铺被用户点击次数，加购次数，购买次数，收藏次数

# %%
# 点击次数
all_data_test = user_col_cnt(all_data_test,  ['seller_path'], '0', 'user_cnt_0')
# 加购次数
all_data_test = user_col_cnt(all_data_test,  ['seller_path'], '1', 'user_cnt_1')
# 购买次数
all_data_test = user_col_cnt(all_data_test,  ['seller_path'], '2', 'user_cnt_2')
# 收藏次数
all_data_test = user_col_cnt(all_data_test,  ['seller_path'], '3', 'user_cnt_3')


# 不同店铺个数
all_data_test = user_col_nunique(all_data_test,  ['seller_path'], '0', 'seller_nunique_0')
# ....

# %% [markdown]
# ## 组合特征
#
# ### 特征组合进行业务特征提取

# %%
# 点击次数
all_data_test = user_col_cnt(all_data_test,  ['seller_path', 'item_path'], '0', 'user_cnt_0')

# 不同店铺个数
all_data_test = user_col_nunique(all_data_test,  ['seller_path', 'item_path'], '0', 'seller_nunique_0')
# ....

# %% [markdown]
# ### 查看提取的特征

# %%
all_data_test.columns
# Out:
# Index(['user_id', 'merchant_id', 'label', 'prob', 'age_range', 'gender',
#        'item_path', 'cat_path', 'seller_path', 'brand_path', 'time_stamp_path',
#        'action_type_path', 'user_cnt', 'seller_nunique', 'cat_nunique',
#        'brand_nunique', 'item_nunique', 'time_stamp_nunique',
#        'action_type_nunique', 'time_stamp_max', 'time_stamp_min',
#        'time_stamp_std', 'time_stamp_range', 'seller_most_1', 'cat_most_1',
#        'brand_most_1', 'action_type_1', 'seller_most_1_cnt', 'cat_most_1_cnt',
#        'brand_most_1_cnt', 'action_type_1_cnt', 'user_cnt_0', 'user_cnt_1',
#        'user_cnt_2', 'user_cnt_3', 'seller_nunique_0'],
#       dtype='object')

# %% [markdown]
# ## 用countvector，tfidf提取特征

# %%
"""
用countvector，tfidf提取特征
"""
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, ENGLISH_STOP_WORDS
from scipy import sparse
# cntVec = CountVectorizer(stop_words=ENGLISH_STOP_WORDS, ngram_range=(1, 1), max_features=100)
tfidfVec = TfidfVectorizer(stop_words=ENGLISH_STOP_WORDS, ngram_range=(1, 1), max_features=100)


# columns_list = ['seller_path', 'cat_path', 'brand_path', 'action_type_path', 'item_path', 'time_stamp_path']
columns_list = ['seller_path']
for i, col in enumerate(columns_list):
	tfidfVec.fit(all_data_test[col])
	data_ = tfidfVec.transform(all_data_test[col])
	if i == 0:
		data_cat = data_
	else:
		data_cat = sparse.hstack((data_cat, data_))

# %% [markdown]
# ### 特征重命名,特征合并

# %%
df_tfidf = pd.DataFrame(data_cat.toarray())
df_tfidf.columns = ['tfidf_' + str(i) for i in df_tfidf.columns]
all_data_test = pd.concat([all_data_test, df_tfidf],axis=1)

# %% [markdown]
# ## embeeding特征

# %%
import gensim

# Train Word2Vec model

model = gensim.models.Word2Vec(all_data_test['seller_path'].apply(lambda x: x.split(' ')), size=100, window=5, min_count=5, workers=4)
# model.save("product2vec.model")
# model = gensim.models.Word2Vec.load("product2vec.model")

def mean_w2v_(x, model, size=100):
    try:
        i = 0
        for word in x.split(' '):
            if word in model.wv.vocab:
                i += 1
                if i == 1:
                    vec = np.zeros(size)
                vec += model.wv[word]
        return vec / i 
    except:
        return  np.zeros(size)


def get_mean_w2v(df_data, columns, model, size):
    data_array = []
    for index, row in df_data.iterrows():
        w2v = mean_w2v_(row[columns], model, size)
        data_array.append(w2v)
    return pd.DataFrame(data_array)

df_embeeding = get_mean_w2v(all_data_test, 'seller_path', model, 100)
df_embeeding.columns = ['embeeding_' + str(i) for i in df_embeeding.columns]

# %% [markdown]
# ### embeeding特征和原始特征合并

# %%
all_data_test = pd.concat([all_data_test, df_embeeding],axis=1)

# %% [markdown]
# ## stacking特征

# %%
"""
stacking特征
"""
# from sklearn.cross_validation import KFold
# from sklearn.model_selection import KFold
import pandas as pd
import numpy as np
from scipy import sparse
import xgboost
import lightgbm
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier,ExtraTreesClassifier
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,ExtraTreesRegressor
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.svm import LinearSVC,SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import log_loss,mean_absolute_error,mean_squared_error
from sklearn.naive_bayes import MultinomialNB,GaussianNB

# %% [markdown]
# ### stacking 回归特征

# %%
"""
stacking回归特征 这里不用，但是很有学习价值
"""
def stacking_reg(clf,train_x,train_y,test_x,clf_name,kf,label_split=None):
    train=np.zeros((train_x.shape[0],1))
    test=np.zeros((test_x.shape[0],1))
    test_pre=np.empty((folds,test_x.shape[0],1))
    cv_scores=[]
    for i,(train_index,test_index) in enumerate(kf.split(train_x,label_split)):       
        tr_x=train_x[train_index]
        tr_y=train_y[train_index]
        te_x=train_x[test_index]
        te_y = train_y[test_index]
        if clf_name in ["rf","ada","gb","et","lr"]:
            clf.fit(tr_x,tr_y)
            pre=clf.predict(te_x).reshape(-1,1)
            train[test_index]=pre
            test_pre[i,:]=clf.predict(test_x).reshape(-1,1)
            cv_scores.append(mean_squared_error(te_y, pre))
        elif clf_name in ["xgb"]:
            train_matrix = clf.DMatrix(tr_x, label=tr_y, missing=-1)
            test_matrix = clf.DMatrix(te_x, label=te_y, missing=-1)
            z = clf.DMatrix(test_x, label=te_y, missing=-1)
            params = {'booster': 'gbtree',
                      'eval_metric': 'rmse',
                      'gamma': 1,
                      'min_child_weight': 1.5,
                      'max_depth': 5,
                      'lambda': 10,
                      'subsample': 0.7,
                      'colsample_bytree': 0.7,
                      'colsample_bylevel': 0.7,
                      'eta': 0.03,
                      'tree_method': 'exact',
                      'seed': 2020,
                      'nthread': 12
                      }
            num_round = 10000
            early_stopping_rounds = 100
            watchlist = [(train_matrix, 'train'),
                         (test_matrix, 'eval')
                         ]
            if test_matrix:
                model = clf.train(params, train_matrix, num_boost_round=num_round,evals=watchlist,
                                  early_stopping_rounds=early_stopping_rounds
                                  )
                pre= model.predict(test_matrix,ntree_limit=model.best_ntree_limit).reshape(-1,1)
                train[test_index]=pre
                test_pre[i, :]= model.predict(z, ntree_limit=model.best_ntree_limit).reshape(-1,1)
                cv_scores.append(mean_squared_error(te_y, pre))

        elif clf_name in ["lgb"]:
            train_matrix = clf.Dataset(tr_x, label=tr_y)
            test_matrix = clf.Dataset(te_x, label=te_y)
            params = {
                      'boosting_type': 'gbdt',
                      'objective': 'regression_l2',
                      'metric': 'mse',
                      'min_child_weight': 1.5,
                      'num_leaves': 2**5,
                      'lambda_l2': 10,
                      'subsample': 0.7,
                      'colsample_bytree': 0.7,
                      'colsample_bylevel': 0.7,
                      'learning_rate': 0.03,
                      'tree_method': 'exact',
                      'seed': 2020,
                      'nthread': 12,
                      'silent': True,
                      }
            num_round = 10000
            early_stopping_rounds = 100
            if test_matrix:
                model = clf.train(params, train_matrix,num_round,valid_sets=test_matrix,
                                  early_stopping_rounds=early_stopping_rounds
                                  )
                pre= model.predict(te_x,num_iteration=model.best_iteration).reshape(-1,1)
                train[test_index]=pre
                test_pre[i, :]= model.predict(test_x, num_iteration=model.best_iteration).reshape(-1,1)
                cv_scores.append(mean_squared_error(te_y, pre))
        else:
            raise IOError("Please add new clf.")
        print("%s now score is:"%clf_name,cv_scores)
    test[:]=test_pre.mean(axis=0)
    print("%s_score_list:"%clf_name,cv_scores)
    print("%s_score_mean:"%clf_name,np.mean(cv_scores))
    return train.reshape(-1,1),test.reshape(-1,1)

def rf_reg(x_train, y_train, x_valid, kf, label_split=None):
    randomforest = RandomForestRegressor(n_estimators=600, max_depth=20, n_jobs=-1, random_state=2017, max_features="auto",verbose=1)
    rf_train, rf_test = stacking_reg(randomforest, x_train, y_train, x_valid, "rf", kf, label_split=label_split)
    return rf_train, rf_test,"rf_reg"

def ada_reg(x_train, y_train, x_valid, kf, label_split=None):
    adaboost = AdaBoostRegressor(n_estimators=30, random_state=2017, learning_rate=0.01)
    ada_train, ada_test = stacking_reg(adaboost, x_train, y_train, x_valid, "ada", kf, label_split=label_split)
    return ada_train, ada_test,"ada_reg"

def gb_reg(x_train, y_train, x_valid, kf, label_split=None):
    gbdt = GradientBoostingRegressor(learning_rate=0.04, n_estimators=100, subsample=0.8, random_state=2017,max_depth=5,verbose=1)
    gbdt_train, gbdt_test = stacking_reg(gbdt, x_train, y_train, x_valid, "gb", kf, label_split=label_split)
    return gbdt_train, gbdt_test,"gb_reg"

def et_reg(x_train, y_train, x_valid, kf, label_split=None):
    extratree = ExtraTreesRegressor(n_estimators=600, max_depth=35, max_features="auto", n_jobs=-1, random_state=2017,verbose=1)
    et_train, et_test = stacking_reg(extratree, x_train, y_train, x_valid, "et", kf, label_split=label_split)
    return et_train, et_test,"et_reg"

def lr_reg(x_train, y_train, x_valid, kf, label_split=None):
    lr_reg=LinearRegression(n_jobs=-1)
    lr_train, lr_test = stacking_reg(lr_reg, x_train, y_train, x_valid, "lr", kf, label_split=label_split)
    return lr_train, lr_test, "lr_reg"

def xgb_reg(x_train, y_train, x_valid, kf, label_split=None):
    xgb_train, xgb_test = stacking_reg(xgboost, x_train, y_train, x_valid, "xgb", kf, label_split=label_split)
    return xgb_train, xgb_test,"xgb_reg"

def lgb_reg(x_train, y_train, x_valid, kf, label_split=None):
    lgb_train, lgb_test = stacking_reg(lightgbm, x_train, y_train, x_valid, "lgb", kf, label_split=label_split)
    return lgb_train, lgb_test,"lgb_reg"

# %% [markdown]
# ### stacking 分类特征

# %%
"""
stacking 分类特征
"""
def stacking_clf(clf,train_x,train_y,test_x,clf_name,kf,label_split=None):
    train=np.zeros((train_x.shape[0],1))
    test=np.zeros((test_x.shape[0],1))
    test_pre=np.empty((folds,test_x.shape[0],1))
    cv_scores=[]
    for i,(train_index,test_index) in enumerate(kf.split(train_x,label_split)):       
        tr_x=train_x[train_index]
        tr_y=train_y[train_index]
        te_x=train_x[test_index]
        te_y = train_y[test_index]

        if clf_name in ["rf","ada","gb","et","lr","knn","gnb"]:
            clf.fit(tr_x,tr_y)
            pre=clf.predict_proba(te_x)
            
            train[test_index]=pre[:,0].reshape(-1,1)
            test_pre[i,:]=clf.predict_proba(test_x)[:,0].reshape(-1,1)
            
            cv_scores.append(log_loss(te_y, pre[:,0].reshape(-1,1)))
        elif clf_name in ["xgb"]:
            train_matrix = clf.DMatrix(tr_x, label=tr_y, missing=-1)
            test_matrix = clf.DMatrix(te_x, label=te_y, missing=-1)
            z = clf.DMatrix(test_x, label=te_y, missing=-1)
            params = {'booster': 'gbtree',
                      'objective': 'multi:softprob',
                      'eval_metric': 'mlogloss',
                      'gamma': 1,
                      'min_child_weight': 1.5,
                      'max_depth': 5,
                      'lambda': 10,
                      'subsample': 0.7,
                      'colsample_bytree': 0.7,
                      'colsample_bylevel': 0.7,
                      'eta': 0.03,
                      'tree_method': 'exact',
                      'seed': 2020,
                      "num_class": 2
                      }

            num_round = 10000
            early_stopping_rounds = 100
            watchlist = [(train_matrix, 'train'),
                         (test_matrix, 'eval')
                         ]
            if test_matrix:
                model = clf.train(params, train_matrix, num_boost_round=num_round,evals=watchlist,
                                  early_stopping_rounds=early_stopping_rounds
                                  )
                pre= model.predict(test_matrix,ntree_limit=model.best_ntree_limit)
                train[test_index]=pre[:,0].reshape(-1,1)
                test_pre[i, :]= model.predict(z, ntree_limit=model.best_ntree_limit)[:,0].reshape(-1,1)
                cv_scores.append(log_loss(te_y, pre[:,0].reshape(-1,1)))
        elif clf_name in ["lgb"]:
            train_matrix = clf.Dataset(tr_x, label=tr_y)
            test_matrix = clf.Dataset(te_x, label=te_y)
            params = {
                      'boosting_type': 'gbdt',
                      #'boosting_type': 'dart',
                      'objective': 'multiclass',
                      'metric': 'multi_logloss',
                      'min_child_weight': 1.5,
                      'num_leaves': 2**5,
                      'lambda_l2': 10,
                      'subsample': 0.7,
                      'colsample_bytree': 0.7,
                      'colsample_bylevel': 0.7,
                      'learning_rate': 0.03,
                      'tree_method': 'exact',
                      'seed': 2020,
                      "num_class": 2,
                      'silent': True,
                      }
            num_round = 10000
            early_stopping_rounds = 100
            if test_matrix:
                model = clf.train(params, train_matrix,num_round,valid_sets=test_matrix,
                                  early_stopping_rounds=early_stopping_rounds
                                  )
                pre= model.predict(te_x,num_iteration=model.best_iteration)
                train[test_index]=pre[:,0].reshape(-1,1)
                test_pre[i, :]= model.predict(test_x, num_iteration=model.best_iteration)[:,0].reshape(-1,1)
                cv_scores.append(log_loss(te_y, pre[:,0].reshape(-1,1)))
        else:
            raise IOError("Please add new clf.")
        print("%s now score is:"%clf_name,cv_scores)
    test[:]=test_pre.mean(axis=0)
    print("%s_score_list:"%clf_name,cv_scores)
    print("%s_score_mean:"%clf_name,np.mean(cv_scores))
    return train.reshape(-1,1),test.reshape(-1,1)

def rf_clf(x_train, y_train, x_valid, kf, label_split=None):
    randomforest = RandomForestClassifier(n_estimators=1200, max_depth=20, n_jobs=-1, random_state=2017, max_features="auto",verbose=1)
    rf_train, rf_test = stacking_clf(randomforest, x_train, y_train, x_valid, "rf", kf, label_split=label_split)
    return rf_train, rf_test,"rf"

def ada_clf(x_train, y_train, x_valid, kf, label_split=None):
    adaboost = AdaBoostClassifier(n_estimators=50, random_state=2017, learning_rate=0.01)
    ada_train, ada_test = stacking_clf(adaboost, x_train, y_train, x_valid, "ada", kf, label_split=label_split)
    return ada_train, ada_test,"ada"

def gb_clf(x_train, y_train, x_valid, kf, label_split=None):
    gbdt = GradientBoostingClassifier(learning_rate=0.04, n_estimators=100, subsample=0.8, random_state=2017,max_depth=5,verbose=1)
    gbdt_train, gbdt_test = stacking_clf(gbdt, x_train, y_train, x_valid, "gb", kf, label_split=label_split)
    return gbdt_train, gbdt_test,"gb"

def et_clf(x_train, y_train, x_valid, kf, label_split=None):
    extratree = ExtraTreesClassifier(n_estimators=1200, max_depth=35, max_features="auto", n_jobs=-1, random_state=2017,verbose=1)
    et_train, et_test = stacking_clf(extratree, x_train, y_train, x_valid, "et", kf, label_split=label_split)
    return et_train, et_test,"et"

def xgb_clf(x_train, y_train, x_valid, kf, label_split=None):
    xgb_train, xgb_test = stacking_clf(xgboost, x_train, y_train, x_valid, "xgb", kf, label_split=label_split)
    return xgb_train, xgb_test,"xgb"

def lgb_clf(x_train, y_train, x_valid, kf, label_split=None):
    xgb_train, xgb_test = stacking_clf(lightgbm, x_train, y_train, x_valid, "lgb", kf, label_split=label_split)
    return xgb_train, xgb_test,"lgb"

def gnb_clf(x_train, y_train, x_valid, kf, label_split=None):
    gnb=GaussianNB()
    gnb_train, gnb_test = stacking_clf(gnb, x_train, y_train, x_valid, "gnb", kf, label_split=label_split)
    return gnb_train, gnb_test,"gnb"

def lr_clf(x_train, y_train, x_valid, kf, label_split=None):
    logisticregression=LogisticRegression(n_jobs=-1,random_state=2017,C=0.1,max_iter=200)
    lr_train, lr_test = stacking_clf(logisticregression, x_train, y_train, x_valid, "lr", kf, label_split=label_split)
    return lr_train, lr_test, "lr"

def knn_clf(x_train, y_train, x_valid, kf, label_split=None):
    kneighbors=KNeighborsClassifier(n_neighbors=200,n_jobs=-1)
    knn_train, knn_test = stacking_clf(kneighbors, x_train, y_train, x_valid, "lr", kf, label_split=label_split)
    return knn_train, knn_test, "knn"

# %% [markdown]
# ### 获取训练和验证数据(为stacking特征做准备)

# %%
features_columns = [c for c in all_data_test.columns if c not in ['label', 'prob', 'seller_path', 'cat_path', 'brand_path', 'action_type_path', 'item_path', 'time_stamp_path']]
x_train = all_data_test[~all_data_test['label'].isna()][features_columns].values
y_train = all_data_test[~all_data_test['label'].isna()]['label'].values
x_valid = all_data_test[all_data_test['label'].isna()][features_columns].values

# %% [markdown]
# ### 处理函数值inf，nan情况

# %%
def get_matrix(data):
    where_are_nan = np.isnan(data)
    where_are_inf = np.isinf(data)
    data[where_are_nan] = 0
    data[where_are_inf] = 0
    return data

# %%
x_train = np.float_(get_matrix(np.float_(x_train)))
y_train = np.int_(y_train)
# x_valid = x_train
x_valid = np.float_(get_matrix(np.float_(x_valid)))

# %% [markdown]
# ### 导入划分数据函数 设stacking特征为5折

# %%
from sklearn.model_selection import StratifiedKFold, KFold
folds = 5
seed = 1
kf = KFold(n_splits=5, shuffle=True, random_state=0)

# %% [markdown]
# ### 使用lgb和xgb分类模型构造stacking特征

# %%
# clf_list = [lgb_clf, xgb_clf, lgb_reg, xgb_reg]
# clf_list_col = ['lgb_clf', 'xgb_clf', 'lgb_reg', 'xgb_reg']

# clf_list = [lgb_clf, xgb_clf]
# clf_list_col = ['lgb_clf', 'xgb_clf']

clf_list = [lgb_clf]
clf_list_col = ['lgb_clf']

# %% [markdown]
# ### 训练模型，获取stacking特征

# %%
clf_list = clf_list
column_list = []
train_data_list=[]
test_data_list=[]
for clf in clf_list:
    train_data,test_data,clf_name=clf(x_train, y_train, x_valid, kf, label_split=None)
    train_data_list.append(train_data)
    test_data_list.append(test_data)
train_stacking = np.concatenate(train_data_list, axis=1)
test_stacking = np.concatenate(test_data_list, axis=1)
# Out:
# [1]	valid_0's multi_logloss: 0.228902
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.228767
# [3]	valid_0's multi_logloss: 0.22863
# [4]	valid_0's multi_logloss: 0.228494
# [5]	valid_0's multi_logloss: 0.228371
# [6]	valid_0's multi_logloss: 0.228264
# [7]	valid_0's multi_logloss: 0.228144
# [8]	valid_0's multi_logloss: 0.22803
# [9]	valid_0's multi_logloss: 0.227933
# [10]	valid_0's multi_logloss: 0.227833
# [11]	valid_0's multi_logloss: 0.227741
# [12]	valid_0's multi_logloss: 0.227649
# [13]	valid_0's multi_logloss: 0.227559
# [14]	valid_0's multi_logloss: 0.227483
# [15]	valid_0's multi_logloss: 0.227408
# [16]	valid_0's multi_logloss: 0.227325
# [17]	valid_0's multi_logloss: 0.227241
# [18]	valid_0's multi_logloss: 0.22717
# [19]	valid_0's multi_logloss: 0.227102
# [20]	valid_0's multi_logloss: 0.227022
# [21]	valid_0's multi_logloss: 0.226959
# [22]	valid_0's multi_logloss: 0.226896
# [23]	valid_0's multi_logloss: 0.226827
# [24]	valid_0's multi_logloss: 0.226768
# [25]	valid_0's multi_logloss: 0.226714
# [26]	valid_0's multi_logloss: 0.226647
# [27]	valid_0's multi_logloss: 0.226591
# [28]	valid_0's multi_logloss: 0.226532
# [29]	valid_0's multi_logloss: 0.226475
# [30]	valid_0's multi_logloss: 0.226427
# [31]	valid_0's multi_logloss: 0.226369
# [32]	valid_0's multi_logloss: 0.226308
# [33]	valid_0's multi_logloss: 0.226254
# [34]	valid_0's multi_logloss: 0.226189
# [35]	valid_0's multi_logloss: 0.226148
# [36]	valid_0's multi_logloss: 0.226091
# [37]	valid_0's multi_logloss: 0.226043
# [38]	valid_0's multi_logloss: 0.226
# [39]	valid_0's multi_logloss: 0.225953
# [40]	valid_0's multi_logloss: 0.225907
# [41]	valid_0's multi_logloss: 0.225864
# [42]	valid_0's multi_logloss: 0.225817
# [43]	valid_0's multi_logloss: 0.225776
# [44]	valid_0's multi_logloss: 0.225737
# [45]	valid_0's multi_logloss: 0.225704
# [46]	valid_0's multi_logloss: 0.225664
# [47]	valid_0's multi_logloss: 0.225629
# [48]	valid_0's multi_logloss: 0.225593
# [49]	valid_0's multi_logloss: 0.225565
# [50]	valid_0's multi_logloss: 0.225531
# [51]	valid_0's multi_logloss: 0.225513
# [52]	valid_0's multi_logloss: 0.225481
# [53]	valid_0's multi_logloss: 0.225454
# [54]	valid_0's multi_logloss: 0.22542
# [55]	valid_0's multi_logloss: 0.225397
# [56]	valid_0's multi_logloss: 0.225365
# [57]	valid_0's multi_logloss: 0.225328
# [58]	valid_0's multi_logloss: 0.2253
# [59]	valid_0's multi_logloss: 0.225276
# [60]	valid_0's multi_logloss: 0.225249
# [61]	valid_0's multi_logloss: 0.225226
# [62]	valid_0's multi_logloss: 0.225197
# [63]	valid_0's multi_logloss: 0.225171
# [64]	valid_0's multi_logloss: 0.225139
# [65]	valid_0's multi_logloss: 0.225116
# [66]	valid_0's multi_logloss: 0.225082
# [67]	valid_0's multi_logloss: 0.225057
# [68]	valid_0's multi_logloss: 0.225034
# [69]	valid_0's multi_logloss: 0.225015
# [70]	valid_0's multi_logloss: 0.224992
# [71]	valid_0's multi_logloss: 0.224974
# [72]	valid_0's multi_logloss: 0.224949
# [73]	valid_0's multi_logloss: 0.224934
# [74]	valid_0's multi_logloss: 0.22491
# [75]	valid_0's multi_logloss: 0.22489
# [76]	valid_0's multi_logloss: 0.224859
# [77]	valid_0's multi_logloss: 0.224841
# [78]	valid_0's multi_logloss: 0.224818
# [79]	valid_0's multi_logloss: 0.224792
# [80]	valid_0's multi_logloss: 0.224768
# [81]	valid_0's multi_logloss: 0.224746
# [82]	valid_0's multi_logloss: 0.224731
# [83]	valid_0's multi_logloss: 0.224708
# [84]	valid_0's multi_logloss: 0.22469
# [85]	valid_0's multi_logloss: 0.224675
# [86]	valid_0's multi_logloss: 0.224653
# [87]	valid_0's multi_logloss: 0.22464
# [88]	valid_0's multi_logloss: 0.224626
# [89]	valid_0's multi_logloss: 0.224615
# [90]	valid_0's multi_logloss: 0.224587
# [91]	valid_0's multi_logloss: 0.224556
# [92]	valid_0's multi_logloss: 0.224531
# [93]	valid_0's multi_logloss: 0.224518
# [94]	valid_0's multi_logloss: 0.224495
# [95]	valid_0's multi_logloss: 0.224485
# [96]	valid_0's multi_logloss: 0.224459
# [97]	valid_0's multi_logloss: 0.224432
# [98]	valid_0's multi_logloss: 0.22441
# [99]	valid_0's multi_logloss: 0.224404
# [100]	valid_0's multi_logloss: 0.224384
# [101]	valid_0's multi_logloss: 0.224347
# [102]	valid_0's multi_logloss: 0.224339
# [103]	valid_0's multi_logloss: 0.22432
# [104]	valid_0's multi_logloss: 0.224308
# [105]	valid_0's multi_logloss: 0.224286
# [106]	valid_0's multi_logloss: 0.224266
# [107]	valid_0's multi_logloss: 0.224251
# [108]	valid_0's multi_logloss: 0.224242
# [109]	valid_0's multi_logloss: 0.224215
# [110]	valid_0's multi_logloss: 0.224209
# [111]	valid_0's multi_logloss: 0.224195
# [112]	valid_0's multi_logloss: 0.224184
# [113]	valid_0's multi_logloss: 0.224165
# [114]	valid_0's multi_logloss: 0.224157
# [115]	valid_0's multi_logloss: 0.224157
# [116]	valid_0's multi_logloss: 0.224152
# [117]	valid_0's multi_logloss: 0.224124
# [118]	valid_0's multi_logloss: 0.224086
# [119]	valid_0's multi_logloss: 0.224071
# [120]	valid_0's multi_logloss: 0.224058
# [121]	valid_0's multi_logloss: 0.224048
# [122]	valid_0's multi_logloss: 0.224044
# [123]	valid_0's multi_logloss: 0.224033
# [124]	valid_0's multi_logloss: 0.224026
# [125]	valid_0's multi_logloss: 0.224012
# [126]	valid_0's multi_logloss: 0.224
# [127]	valid_0's multi_logloss: 0.22396
# [128]	valid_0's multi_logloss: 0.22395
# [129]	valid_0's multi_logloss: 0.223948
# [130]	valid_0's multi_logloss: 0.223932
# [131]	valid_0's multi_logloss: 0.223922
# [132]	valid_0's multi_logloss: 0.223921
# [133]	valid_0's multi_logloss: 0.223898
# [134]	valid_0's multi_logloss: 0.223894
# [135]	valid_0's multi_logloss: 0.223891
# [136]	valid_0's multi_logloss: 0.223877
# [137]	valid_0's multi_logloss: 0.223862
# [138]	valid_0's multi_logloss: 0.223858
# [139]	valid_0's multi_logloss: 0.223846
# [140]	valid_0's multi_logloss: 0.223833
# [141]	valid_0's multi_logloss: 0.223828
# [142]	valid_0's multi_logloss: 0.223818
# [143]	valid_0's multi_logloss: 0.223811
# [144]	valid_0's multi_logloss: 0.223804
# [145]	valid_0's multi_logloss: 0.223794
# [146]	valid_0's multi_logloss: 0.223782
# [147]	valid_0's multi_logloss: 0.223773
# [148]	valid_0's multi_logloss: 0.223767
# [149]	valid_0's multi_logloss: 0.223763
# [150]	valid_0's multi_logloss: 0.223751
# [151]	valid_0's multi_logloss: 0.223738
# [152]	valid_0's multi_logloss: 0.223717
# [153]	valid_0's multi_logloss: 0.223705
# [154]	valid_0's multi_logloss: 0.2237
# [155]	valid_0's multi_logloss: 0.223687
# [156]	valid_0's multi_logloss: 0.223692
# [157]	valid_0's multi_logloss: 0.223684
# [158]	valid_0's multi_logloss: 0.223669
# [159]	valid_0's multi_logloss: 0.223664
# [160]	valid_0's multi_logloss: 0.223659
# [161]	valid_0's multi_logloss: 0.223662
# [162]	valid_0's multi_logloss: 0.223647
# [163]	valid_0's multi_logloss: 0.223644
# [164]	valid_0's multi_logloss: 0.223639
# [165]	valid_0's multi_logloss: 0.223621
# [166]	valid_0's multi_logloss: 0.223613
# [167]	valid_0's multi_logloss: 0.223585
# [168]	valid_0's multi_logloss: 0.223571
# [169]	valid_0's multi_logloss: 0.223567
# [170]	valid_0's multi_logloss: 0.223564
# [171]	valid_0's multi_logloss: 0.22356
# [172]	valid_0's multi_logloss: 0.223558
# [173]	valid_0's multi_logloss: 0.223562
# [174]	valid_0's multi_logloss: 0.223564
# [175]	valid_0's multi_logloss: 0.223556
# [176]	valid_0's multi_logloss: 0.223554
# [177]	valid_0's multi_logloss: 0.223539
# [178]	valid_0's multi_logloss: 0.223531
# [179]	valid_0's multi_logloss: 0.223528
# [180]	valid_0's multi_logloss: 0.223522
# [181]	valid_0's multi_logloss: 0.223511
# [182]	valid_0's multi_logloss: 0.223506
# [183]	valid_0's multi_logloss: 0.223505
# [184]	valid_0's multi_logloss: 0.223497
# [185]	valid_0's multi_logloss: 0.22349
# [186]	valid_0's multi_logloss: 0.223482
# [187]	valid_0's multi_logloss: 0.223474
# [188]	valid_0's multi_logloss: 0.223471
# [189]	valid_0's multi_logloss: 0.223469
# [190]	valid_0's multi_logloss: 0.223471
# [191]	valid_0's multi_logloss: 0.223464
# [192]	valid_0's multi_logloss: 0.223455
# [193]	valid_0's multi_logloss: 0.223445
# [194]	valid_0's multi_logloss: 0.223442
# [195]	valid_0's multi_logloss: 0.223439
# [196]	valid_0's multi_logloss: 0.22343
# [197]	valid_0's multi_logloss: 0.223432
# [198]	valid_0's multi_logloss: 0.223428
# [199]	valid_0's multi_logloss: 0.223423
# [200]	valid_0's multi_logloss: 0.223424
# [201]	valid_0's multi_logloss: 0.22342
# [202]	valid_0's multi_logloss: 0.223416
# [203]	valid_0's multi_logloss: 0.223413
# [204]	valid_0's multi_logloss: 0.223407
# [205]	valid_0's multi_logloss: 0.223402
# [206]	valid_0's multi_logloss: 0.223398
# [207]	valid_0's multi_logloss: 0.223401
# [208]	valid_0's multi_logloss: 0.223394
# [209]	valid_0's multi_logloss: 0.223394
# [210]	valid_0's multi_logloss: 0.223369
# [211]	valid_0's multi_logloss: 0.223366
# [212]	valid_0's multi_logloss: 0.223364
# [213]	valid_0's multi_logloss: 0.223358
# [214]	valid_0's multi_logloss: 0.223353
# [215]	valid_0's multi_logloss: 0.223349
# [216]	valid_0's multi_logloss: 0.223353
# [217]	valid_0's multi_logloss: 0.223353
# [218]	valid_0's multi_logloss: 0.22335
# [219]	valid_0's multi_logloss: 0.223342
# [220]	valid_0's multi_logloss: 0.223346
# [221]	valid_0's multi_logloss: 0.223343
# [222]	valid_0's multi_logloss: 0.223342
# [223]	valid_0's multi_logloss: 0.223339
# [224]	valid_0's multi_logloss: 0.223342
# [225]	valid_0's multi_logloss: 0.223337
# [226]	valid_0's multi_logloss: 0.223334
# [227]	valid_0's multi_logloss: 0.223334
# [228]	valid_0's multi_logloss: 0.223324
# [229]	valid_0's multi_logloss: 0.223319
# [230]	valid_0's multi_logloss: 0.223317
# [231]	valid_0's multi_logloss: 0.223319
# [232]	valid_0's multi_logloss: 0.223315
# [233]	valid_0's multi_logloss: 0.22331
# [234]	valid_0's multi_logloss: 0.223307
# [235]	valid_0's multi_logloss: 0.223312
# [236]	valid_0's multi_logloss: 0.223307
# [237]	valid_0's multi_logloss: 0.223304
# [238]	valid_0's multi_logloss: 0.223302
# [239]	valid_0's multi_logloss: 0.223305
# [240]	valid_0's multi_logloss: 0.223304
# [241]	valid_0's multi_logloss: 0.223304
# [242]	valid_0's multi_logloss: 0.223307
# [243]	valid_0's multi_logloss: 0.223306
# [244]	valid_0's multi_logloss: 0.223307
# [245]	valid_0's multi_logloss: 0.223311
# [246]	valid_0's multi_logloss: 0.223307
# [247]	valid_0's multi_logloss: 0.223302
# [248]	valid_0's multi_logloss: 0.223302
# [249]	valid_0's multi_logloss: 0.223301
# [250]	valid_0's multi_logloss: 0.223302
# [251]	valid_0's multi_logloss: 0.223304
# [252]	valid_0's multi_logloss: 0.223306
# [253]	valid_0's multi_logloss: 0.223312
# [254]	valid_0's multi_logloss: 0.223308
# [255]	valid_0's multi_logloss: 0.223303
# [256]	valid_0's multi_logloss: 0.223303
# [257]	valid_0's multi_logloss: 0.223303
# [258]	valid_0's multi_logloss: 0.223304
# [259]	valid_0's multi_logloss: 0.223306
# [260]	valid_0's multi_logloss: 0.223309
# [261]	valid_0's multi_logloss: 0.223309
# [262]	valid_0's multi_logloss: 0.223306
# [263]	valid_0's multi_logloss: 0.223307
# [264]	valid_0's multi_logloss: 0.223311
# [265]	valid_0's multi_logloss: 0.223312
# [266]	valid_0's multi_logloss: 0.223309
# [267]	valid_0's multi_logloss: 0.223305
# [268]	valid_0's multi_logloss: 0.223305
# [269]	valid_0's multi_logloss: 0.223303
# [270]	valid_0's multi_logloss: 0.223308
# [271]	valid_0's multi_logloss: 0.223302
# [272]	valid_0's multi_logloss: 0.223305
# [273]	valid_0's multi_logloss: 0.223303
# [274]	valid_0's multi_logloss: 0.223304
# [275]	valid_0's multi_logloss: 0.223298
# [276]	valid_0's multi_logloss: 0.223305
# [277]	valid_0's multi_logloss: 0.223308
# [278]	valid_0's multi_logloss: 0.223313
# [279]	valid_0's multi_logloss: 0.223315
# [280]	valid_0's multi_logloss: 0.223312
# [281]	valid_0's multi_logloss: 0.223314
# [282]	valid_0's multi_logloss: 0.223308
# [283]	valid_0's multi_logloss: 0.22331
# [284]	valid_0's multi_logloss: 0.223309
# [285]	valid_0's multi_logloss: 0.223308
# [286]	valid_0's multi_logloss: 0.223297
# [287]	valid_0's multi_logloss: 0.223297
# [288]	valid_0's multi_logloss: 0.223303
# [289]	valid_0's multi_logloss: 0.223302
# [290]	valid_0's multi_logloss: 0.223297
# [291]	valid_0's multi_logloss: 0.223292
# [292]	valid_0's multi_logloss: 0.223289
# [293]	valid_0's multi_logloss: 0.223285
# [294]	valid_0's multi_logloss: 0.223285
# [295]	valid_0's multi_logloss: 0.223285
# [296]	valid_0's multi_logloss: 0.22328
# [297]	valid_0's multi_logloss: 0.223282
# [298]	valid_0's multi_logloss: 0.223284
# [299]	valid_0's multi_logloss: 0.223289
# [300]	valid_0's multi_logloss: 0.223286
# [301]	valid_0's multi_logloss: 0.223286
# [302]	valid_0's multi_logloss: 0.223282
# [303]	valid_0's multi_logloss: 0.223283
# [304]	valid_0's multi_logloss: 0.223286
# [305]	valid_0's multi_logloss: 0.223288
# [306]	valid_0's multi_logloss: 0.223294
# [307]	valid_0's multi_logloss: 0.223292
# [308]	valid_0's multi_logloss: 0.223293
# [309]	valid_0's multi_logloss: 0.223292
# [310]	valid_0's multi_logloss: 0.223289
# [311]	valid_0's multi_logloss: 0.223293
# [312]	valid_0's multi_logloss: 0.223296
# [313]	valid_0's multi_logloss: 0.223296
# [314]	valid_0's multi_logloss: 0.223297
# [315]	valid_0's multi_logloss: 0.223293
# [316]	valid_0's multi_logloss: 0.223294
# [317]	valid_0's multi_logloss: 0.223296
# [318]	valid_0's multi_logloss: 0.223287
# [319]	valid_0's multi_logloss: 0.223287
# [320]	valid_0's multi_logloss: 0.223287
# [321]	valid_0's multi_logloss: 0.223283
# [322]	valid_0's multi_logloss: 0.223281
# [323]	valid_0's multi_logloss: 0.223283
# [324]	valid_0's multi_logloss: 0.223281
# [325]	valid_0's multi_logloss: 0.223279
# [326]	valid_0's multi_logloss: 0.223279
# [327]	valid_0's multi_logloss: 0.223282
# [328]	valid_0's multi_logloss: 0.223283
# [329]	valid_0's multi_logloss: 0.223285
# [330]	valid_0's multi_logloss: 0.223287
# [331]	valid_0's multi_logloss: 0.223283
# [332]	valid_0's multi_logloss: 0.223285
# [333]	valid_0's multi_logloss: 0.223283
# [334]	valid_0's multi_logloss: 0.223284
# [335]	valid_0's multi_logloss: 0.223282
# [336]	valid_0's multi_logloss: 0.223277
# [337]	valid_0's multi_logloss: 0.223275
# [338]	valid_0's multi_logloss: 0.223274
# [339]	valid_0's multi_logloss: 0.223268
# [340]	valid_0's multi_logloss: 0.223265
# [341]	valid_0's multi_logloss: 0.223261
# [342]	valid_0's multi_logloss: 0.22326
# [343]	valid_0's multi_logloss: 0.223258
# [344]	valid_0's multi_logloss: 0.223254
# [345]	valid_0's multi_logloss: 0.223255
# [346]	valid_0's multi_logloss: 0.223248
# [347]	valid_0's multi_logloss: 0.223252
# [348]	valid_0's multi_logloss: 0.22325
# [349]	valid_0's multi_logloss: 0.223247
# [350]	valid_0's multi_logloss: 0.223241
# [351]	valid_0's multi_logloss: 0.22324
# [352]	valid_0's multi_logloss: 0.223242
# [353]	valid_0's multi_logloss: 0.223236
# [354]	valid_0's multi_logloss: 0.223237
# [355]	valid_0's multi_logloss: 0.223236
# [356]	valid_0's multi_logloss: 0.223234
# [357]	valid_0's multi_logloss: 0.223232
# [358]	valid_0's multi_logloss: 0.223232
# [359]	valid_0's multi_logloss: 0.223233
# [360]	valid_0's multi_logloss: 0.223231
# [361]	valid_0's multi_logloss: 0.223231
# [362]	valid_0's multi_logloss: 0.223231
# [363]	valid_0's multi_logloss: 0.223232
# [364]	valid_0's multi_logloss: 0.223229
# [365]	valid_0's multi_logloss: 0.223231
# [366]	valid_0's multi_logloss: 0.223232
# [367]	valid_0's multi_logloss: 0.22323
# [368]	valid_0's multi_logloss: 0.223229
# [369]	valid_0's multi_logloss: 0.223229
# [370]	valid_0's multi_logloss: 0.223233
# [371]	valid_0's multi_logloss: 0.223229
# [372]	valid_0's multi_logloss: 0.223224
# [373]	valid_0's multi_logloss: 0.223222
# [374]	valid_0's multi_logloss: 0.223226
# [375]	valid_0's multi_logloss: 0.223225
# [376]	valid_0's multi_logloss: 0.223226
# [377]	valid_0's multi_logloss: 0.223214
# [378]	valid_0's multi_logloss: 0.223212
# [379]	valid_0's multi_logloss: 0.223209
# [380]	valid_0's multi_logloss: 0.223211
# [381]	valid_0's multi_logloss: 0.22321
# [382]	valid_0's multi_logloss: 0.223207
# [383]	valid_0's multi_logloss: 0.223205
# [384]	valid_0's multi_logloss: 0.223202
# [385]	valid_0's multi_logloss: 0.223196
# [386]	valid_0's multi_logloss: 0.223197
# [387]	valid_0's multi_logloss: 0.223203
# [388]	valid_0's multi_logloss: 0.223207
# [389]	valid_0's multi_logloss: 0.223207
# [390]	valid_0's multi_logloss: 0.223203
# [391]	valid_0's multi_logloss: 0.2232
# [392]	valid_0's multi_logloss: 0.223201
# [393]	valid_0's multi_logloss: 0.223199
# [394]	valid_0's multi_logloss: 0.223202
# [395]	valid_0's multi_logloss: 0.223202
# [396]	valid_0's multi_logloss: 0.223204
# [397]	valid_0's multi_logloss: 0.223204
# [398]	valid_0's multi_logloss: 0.223202
# [399]	valid_0's multi_logloss: 0.223202
# [400]	valid_0's multi_logloss: 0.223204
# [401]	valid_0's multi_logloss: 0.223201
# [402]	valid_0's multi_logloss: 0.223199
# [403]	valid_0's multi_logloss: 0.223202
# [404]	valid_0's multi_logloss: 0.223203
# [405]	valid_0's multi_logloss: 0.223201
# [406]	valid_0's multi_logloss: 0.223197
# [407]	valid_0's multi_logloss: 0.223191
# [408]	valid_0's multi_logloss: 0.223195
# [409]	valid_0's multi_logloss: 0.223198
# [410]	valid_0's multi_logloss: 0.223201
# [411]	valid_0's multi_logloss: 0.223199
# [412]	valid_0's multi_logloss: 0.223199
# [413]	valid_0's multi_logloss: 0.223196
# [414]	valid_0's multi_logloss: 0.223196
# [415]	valid_0's multi_logloss: 0.223198
# [416]	valid_0's multi_logloss: 0.223192
# [417]	valid_0's multi_logloss: 0.223195
# [418]	valid_0's multi_logloss: 0.223197
# [419]	valid_0's multi_logloss: 0.223196
# [420]	valid_0's multi_logloss: 0.2232
# [421]	valid_0's multi_logloss: 0.223205
# [422]	valid_0's multi_logloss: 0.223205
# [423]	valid_0's multi_logloss: 0.223208
# [424]	valid_0's multi_logloss: 0.223211
# [425]	valid_0's multi_logloss: 0.22321
# [426]	valid_0's multi_logloss: 0.223214
# [427]	valid_0's multi_logloss: 0.223213
# [428]	valid_0's multi_logloss: 0.223214
# [429]	valid_0's multi_logloss: 0.22321
# [430]	valid_0's multi_logloss: 0.223207
# [431]	valid_0's multi_logloss: 0.223206
# [432]	valid_0's multi_logloss: 0.22321
# [433]	valid_0's multi_logloss: 0.223209
# [434]	valid_0's multi_logloss: 0.223205
# [435]	valid_0's multi_logloss: 0.223208
# [436]	valid_0's multi_logloss: 0.223205
# [437]	valid_0's multi_logloss: 0.223204
# [438]	valid_0's multi_logloss: 0.223202
# [439]	valid_0's multi_logloss: 0.223205
# [440]	valid_0's multi_logloss: 0.223202
# [441]	valid_0's multi_logloss: 0.223204
# [442]	valid_0's multi_logloss: 0.223203
# [443]	valid_0's multi_logloss: 0.223203
# [444]	valid_0's multi_logloss: 0.223201
# [445]	valid_0's multi_logloss: 0.223205
# [446]	valid_0's multi_logloss: 0.2232
# [447]	valid_0's multi_logloss: 0.223199
# [448]	valid_0's multi_logloss: 0.2232
# [449]	valid_0's multi_logloss: 0.223205
# [450]	valid_0's multi_logloss: 0.223204
# [451]	valid_0's multi_logloss: 0.223206
# [452]	valid_0's multi_logloss: 0.223209
# [453]	valid_0's multi_logloss: 0.223215
# [454]	valid_0's multi_logloss: 0.223218
# [455]	valid_0's multi_logloss: 0.22322
# [456]	valid_0's multi_logloss: 0.223219
# [457]	valid_0's multi_logloss: 0.223224
# [458]	valid_0's multi_logloss: 0.223227
# [459]	valid_0's multi_logloss: 0.223226
# [460]	valid_0's multi_logloss: 0.223224
# [461]	valid_0's multi_logloss: 0.223223
# [462]	valid_0's multi_logloss: 0.223222
# [463]	valid_0's multi_logloss: 0.223224
# [464]	valid_0's multi_logloss: 0.223226
# [465]	valid_0's multi_logloss: 0.223213
# [466]	valid_0's multi_logloss: 0.223214
# [467]	valid_0's multi_logloss: 0.223217
# [468]	valid_0's multi_logloss: 0.223209
# [469]	valid_0's multi_logloss: 0.223212
# [470]	valid_0's multi_logloss: 0.223211
# [471]	valid_0's multi_logloss: 0.22321
# [472]	valid_0's multi_logloss: 0.223214
# [473]	valid_0's multi_logloss: 0.22322
# [474]	valid_0's multi_logloss: 0.22322
# [475]	valid_0's multi_logloss: 0.223216
# [476]	valid_0's multi_logloss: 0.223217
# [477]	valid_0's multi_logloss: 0.223217
# [478]	valid_0's multi_logloss: 0.223216
# [479]	valid_0's multi_logloss: 0.223215
# [480]	valid_0's multi_logloss: 0.223219
# [481]	valid_0's multi_logloss: 0.223223
# [482]	valid_0's multi_logloss: 0.223221
# [483]	valid_0's multi_logloss: 0.223224
# [484]	valid_0's multi_logloss: 0.223224
# [485]	valid_0's multi_logloss: 0.223222
# [486]	valid_0's multi_logloss: 0.223224
# [487]	valid_0's multi_logloss: 0.223225
# [488]	valid_0's multi_logloss: 0.223231
# [489]	valid_0's multi_logloss: 0.223233
# [490]	valid_0's multi_logloss: 0.223236
# [491]	valid_0's multi_logloss: 0.22324
# [492]	valid_0's multi_logloss: 0.223244
# [493]	valid_0's multi_logloss: 0.223245
# [494]	valid_0's multi_logloss: 0.223242
# [495]	valid_0's multi_logloss: 0.223239
# [496]	valid_0's multi_logloss: 0.22324
# [497]	valid_0's multi_logloss: 0.223239
# [498]	valid_0's multi_logloss: 0.223237
# [499]	valid_0's multi_logloss: 0.223239
# [500]	valid_0's multi_logloss: 0.223237
# [501]	valid_0's multi_logloss: 0.223238
# [502]	valid_0's multi_logloss: 0.223236
# [503]	valid_0's multi_logloss: 0.223239
# [504]	valid_0's multi_logloss: 0.223242
# [505]	valid_0's multi_logloss: 0.223248
# [506]	valid_0's multi_logloss: 0.223252
# [507]	valid_0's multi_logloss: 0.22325
# Early stopping, best iteration is:
# [407]	valid_0's multi_logloss: 0.223191
# lgb now score is: [2.702851928277892]
# [1]	valid_0's multi_logloss: 0.231488
# Training until validation scores don't improve for 100 rounds
# [2]	valid_0's multi_logloss: 0.231366
# [3]	valid_0's multi_logloss: 0.231241
# [4]	valid_0's multi_logloss: 0.231117
# [5]	valid_0's multi_logloss: 0.231005
# [6]	valid_0's multi_logloss: 0.230912
# [7]	valid_0's multi_logloss: 0.230804
# [8]	valid_0's multi_logloss: 0.230712
# [9]	valid_0's multi_logloss: 0.230612
# [10]	valid_0's multi_logloss: 0.230523
# [11]	valid_0's multi_logloss: 0.23044
# [12]	valid_0's multi_logloss: 0.23035
# [13]	valid_0's multi_logloss: 0.230265
# [14]	valid_0's multi_logloss: 0.230174
# [15]	valid_0's multi_logloss: 0.230093
# [16]	valid_0's multi_logloss: 0.230015
# [17]	valid_0's multi_logloss: 0.229935
# [18]	valid_0's multi_logloss: 0.229853
# [19]	valid_0's multi_logloss: 0.229789
# [20]	valid_0's multi_logloss: 0.229718
# [21]	valid_0's multi_logloss: 0.229654
# [22]	valid_0's multi_logloss: 0.22959
# [23]	valid_0's multi_logloss: 0.229524
# [24]	valid_0's multi_logloss: 0.22947
# [25]	valid_0's multi_logloss: 0.229405
# [26]	valid_0's multi_logloss: 0.229357
# [27]	valid_0's multi_logloss: 0.2293
# [28]	valid_0's multi_logloss: 0.229251
# [29]	valid_0's multi_logloss: 0.2292
# [30]	valid_0's multi_logloss: 0.229147
# [31]	valid_0's multi_logloss: 0.22911
# [32]	valid_0's multi_logloss: 0.229065
# [33]	valid_0's multi_logloss: 0.229016
# [34]	valid_0's multi_logloss: 0.228963
# [35]	valid_0's multi_logloss: 0.228915
# [36]	valid_0's multi_logloss: 0.228877
# [37]	valid_0's multi_logloss: 0.228836
# [38]	valid_0's multi_logloss: 0.228784
# [39]	valid_0's multi_logloss: 0.228733
# [40]	valid_0's multi_logloss: 0.228701
# [41]	valid_0's multi_logloss: 0.228661
# [42]	valid_0's multi_logloss: 0.228632
# [43]	valid_0's multi_logloss: 0.228594
# [44]	valid_0's multi_logloss: 0.228555
# [45]	valid_0's multi_logloss: 0.228515
# [46]	valid_0's multi_logloss: 0.228479
# [47]	valid_0's multi_logloss: 0.228442
# [48]	valid_0's multi_logloss: 0.228413
# [49]	valid_0's multi_logloss: 0.228376
# [50]	valid_0's multi_logloss: 0.228344
# [51]	valid_0's multi_logloss: 0.228314
# [52]	valid_0's multi_logloss: 0.228292
# [53]	valid_0's multi_logloss: 0.22827
# [54]	valid_0's multi_logloss: 0.228256
# [55]	valid_0's multi_logloss: 0.228229
# [56]	valid_0's multi_logloss: 0.22819
# [57]	valid_0's multi_logloss: 0.228174
# [58]	valid_0's multi_logloss: 0.22813
# [59]	valid_0's multi_logloss: 0.228101
# [60]	valid_0's multi_logloss: 0.228079
# [61]	valid_0's multi_logloss: 0.228054
# [62]	valid_0's multi_logloss: 0.228021
# [63]	valid_0's multi_logloss: 0.228
# [64]	valid_0's multi_logloss: 0.227976
# [65]	valid_0's multi_logloss: 0.227946
# [66]	valid_0's multi_logloss: 0.227925
# [67]	valid_0's multi_logloss: 0.227892
# [68]	valid_0's multi_logloss: 0.227865
# [69]	valid_0's multi_logloss: 0.227846
# [70]	valid_0's multi_logloss: 0.227831
# [71]	valid_0's multi_logloss: 0.227818
# [72]	valid_0's multi_logloss: 0.227797
# [73]	valid_0's multi_logloss: 0.227765
# [74]	valid_0's multi_logloss: 0.227747
# [75]	valid_0's multi_logloss: 0.227724
# [76]	valid_0's multi_logloss: 0.227705
# [77]	valid_0's multi_logloss: 0.22769
# [78]	valid_0's multi_logloss: 0.227662
# [79]	valid_0's multi_logloss: 0.227649
# [80]	valid_0's multi_logloss: 0.227634
# [81]	valid_0's multi_logloss: 0.227608
# [82]	valid_0's multi_logloss: 0.227596
# [83]	valid_0's multi_logloss: 0.227578
# [84]	valid_0's multi_logloss: 0.227565
# [85]	valid_0's multi_logloss: 0.227542
# [86]	valid_0's multi_logloss: 0.227526
# [87]	valid_0's multi_logloss: 0.227507
# [88]	valid_0's multi_logloss: 0.227493
# [89]	valid_0's multi_logloss: 0.227486
# [90]	valid_0's multi_logloss: 0.227473
# [91]	valid_0's multi_logloss: 0.227447
# [92]	valid_0's multi_logloss: 0.227436
# [93]	valid_0's multi_logloss: 0.227411
# [94]	valid_0's multi_logloss: 0.227389
# [95]	valid_0's multi_logloss: 0.22735
# [96]	valid_0's multi_logloss: 0.227325
# [97]	valid_0's multi_logloss: 0.227313
# [98]	valid_0's multi_logloss: 0.227281
# [99]	valid_0's multi_logloss: 0.227272
# [100]	valid_0's multi_logloss: 0.227255
# [101]	valid_0's multi_logloss: 0.227225
# [102]	valid_0's multi_logloss: 0.227216
# [103]	valid_0's multi_logloss: 0.227209
# [104]	valid_0's multi_logloss: 0.227199
# [105]	valid_0's multi_logloss: 0.227194
# [106]	valid_0's multi_logloss: 0.227186
# [107]	valid_0's multi_logloss: 0.227152
# [108]	valid_0's multi_logloss: 0.227137
# [109]	valid_0's multi_logloss: 0.227118
# [110]	valid_0's multi_logloss: 0.227114
# [111]	valid_0's multi_logloss: 0.227099
# [112]	valid_0's multi_logloss: 0.227069
# [113]	valid_0's multi_logloss: 0.227069
# [114]	valid_0's multi_logloss: 0.22706
# [115]	valid_0's multi_logloss: 0.227052
# [116]	valid_0's multi_logloss: 0.227039
# [117]	valid_0's multi_logloss: 0.227026
# [118]	valid_0's multi_logloss: 0.227017
# [119]	valid_0's multi_logloss: 0.22698
# [120]	valid_0's multi_logloss: 0.226966
# [121]	valid_0's multi_logloss: 0.226966
# [122]	valid_0's multi_logloss: 0.226954
# [123]	valid_0's multi_logloss: 0.226944
# [124]	valid_0's multi_logloss: 0.226941
# [125]	valid_0's multi_logloss: 0.226922
# [126]	valid_0's multi_logloss: 0.226896
# [127]	valid_0's multi_logloss: 0.226885
# [128]	valid_0's multi_logloss: 0.226876
# [129]	valid_0's multi_logloss: 0.226874
# [130]	valid_0's multi_logloss: 0.226865
# [131]	valid_0's multi_logloss: 0.226854
# [132]	valid_0's multi_logloss: 0.226822
# [133]	valid_0's multi_logloss: 0.226777
# [134]	valid_0's multi_logloss: 0.226772
# [135]	valid_0's multi_logloss: 0.226767
# [136]	valid_0's multi_logloss: 0.226767
# [137]	valid_0's multi_logloss: 0.226772
# [138]	valid_0's multi_logloss: 0.22677
# [139]	valid_0's multi_logloss: 0.226759
# [140]	valid_0's multi_logloss: 0.226734
# [141]	valid_0's multi_logloss: 0.226725
# [142]	valid_0's multi_logloss: 0.226712
# [143]	valid_0's multi_logloss: 0.226705
# [144]	valid_0's multi_logloss: 0.226699
# [145]	valid_0's multi_logloss: 0.226694
# [146]	valid_0's multi_logloss: 0.226693
# [147]	valid_0's multi_logloss: 0.226689
# [148]	valid_0's multi_logloss: 0.226683
# [149]	valid_0's multi_logloss: 0.226677
# [150]	valid_0's multi_logloss: 0.226665
# [151]	valid_0's multi_logloss: 0.226673
# [152]	valid_0's multi_logloss: 0.226657
# [153]	valid_0's multi_logloss: 0.226644
# [154]	valid_0's multi_logloss: 0.226645
# [155]	valid_0's multi_logloss: 0.226642
# [156]	valid_0's multi_logloss: 0.226633
# [157]	valid_0's multi_logloss: 0.226628
# [158]	valid_0's multi_logloss: 0.226622
# [159]	valid_0's multi_logloss: 0.226606
# [160]	valid_0's multi_logloss: 0.226605
# [161]	valid_0's multi_logloss: 0.226603
# [162]	valid_0's multi_logloss: 0.226601
# [163]	valid_0's multi_logloss: 0.226595
# [164]	valid_0's multi_logloss: 0.226587
# [165]	valid_0's multi_logloss: 0.226588
# [166]	valid_0's multi_logloss: 0.226571
# [167]	valid_0's multi_logloss: 0.226533
# [168]	valid_0's multi_logloss: 0.226528
# [169]	valid_0's multi_logloss: 0.226526
# [170]	valid_0's multi_logloss: 0.22652
# [171]	valid_0's multi_logloss: 0.226517
# [172]	valid_0's multi_logloss: 0.226512
# [173]	valid_0's multi_logloss: 0.2265
# [174]	valid_0's multi_logloss: 0.226498
# [175]	valid_0's multi_logloss: 0.226502
# [176]	valid_0's multi_logloss: 0.226502
# [177]	valid_0's multi_logloss: 0.226502
# [178]	valid_0's multi_logloss: 0.226498
# [179]	valid_0's multi_logloss: 0.226494
# [180]	valid_0's multi_logloss: 0.226486
# [181]	valid_0's multi_logloss: 0.226486
# [182]	valid_0's multi_logloss: 0.226484
# [183]	valid_0's multi_logloss: 0.226471
# [184]	valid_0's multi_logloss: 0.226466
# [185]	valid_0's multi_logloss: 0.22646
# [186]	valid_0's multi_logloss: 0.226448
# [187]	valid_0's multi_logloss: 0.226444
# [188]	valid_0's multi_logloss: 0.226441
# [189]	valid_0's multi_logloss: 0.226438
# [190]	valid_0's multi_logloss: 0.22644
# [191]	valid_0's multi_logloss: 0.226438
# [192]	valid_0's multi_logloss: 0.226442
# [193]	valid_0's multi_logloss: 0.226427
# [194]	valid_0's multi_logloss: 0.226422
# [195]	valid_0's multi_logloss: 0.22642
# [196]	valid_0's multi_logloss: 0.226405
# [197]	valid_0's multi_logloss: 0.226409
# [198]	valid_0's multi_logloss: 0.226404
# [199]	valid_0's multi_logloss: 0.226398
# [200]	valid_0's multi_logloss: 0.226376
# [201]	valid_0's multi_logloss: 0.22637
# [202]	valid_0's multi_logloss: 0.226367
# [203]	valid_0's multi_logloss: 0.226363
# [204]	valid_0's multi_logloss: 0.226362
# [205]	valid_0's multi_logloss: 0.226364
# [206]	valid_0's multi_logloss: 0.226362
# [207]	valid_0's multi_logloss: 0.22636
# [208]	valid_0's multi_logloss: 0.226357
# [209]	valid_0's multi_logloss: 0.226356
# [210]	valid_0's multi_logloss: 0.226354
# [211]	valid_0's multi_logloss: 0.226349
# [212]	valid_0's multi_logloss: 0.226346
# [213]	valid_0's multi_logloss: 0.226328
# [214]	valid_0's multi_logloss: 0.226327
# [215]	valid_0's multi_logloss: 0.226321
# [216]	valid_0's multi_logloss: 0.226322
# [217]	valid_0's multi_logloss: 0.226322
# [218]	valid_0's multi_logloss: 0.226319
# [219]	valid_0's multi_logloss: 0.226318
# [220]	valid_0's multi_logloss: 0.22632
# [221]	valid_0's multi_logloss: 0.226305
# [222]	valid_0's multi_logloss: 0.22631
# [223]	valid_0's multi_logloss: 0.226302
# [224]	valid_0's multi_logloss: 0.2263
# [225]	valid_0's multi_logloss: 0.226298
# [226]	valid_0's multi_logloss: 0.226298
# [227]	valid_0's multi_logloss: 0.226293
# [228]	valid_0's multi_logloss: 0.22629
# [229]	valid_0's multi_logloss: 0.226281
# [230]	valid_0's multi_logloss: 0.226285
# [231]	valid_0's multi_logloss: 0.226288
# [232]	valid_0's multi_logloss: 0.226284
# [233]	valid_0's multi_logloss: 0.226277
# [234]	valid_0's multi_logloss: 0.226263
# [235]	valid_0's multi_logloss: 0.226246
# [236]	valid_0's multi_logloss: 0.226246
# [237]	valid_0's multi_logloss: 0.226244
# [238]	valid_0's multi_logloss: 0.226244
# [239]	valid_0's multi_logloss: 0.226244
# [240]	valid_0's multi_logloss: 0.226246
# [241]	valid_0's multi_logloss: 0.226243
# [242]	valid_0's multi_logloss: 0.226239
# [243]	valid_0's multi_logloss: 0.226234
# [244]	valid_0's multi_logloss: 0.226234
# [245]	valid_0's multi_logloss: 0.226227
# [246]	valid_0's multi_logloss: 0.226225
# [247]	valid_0's multi_logloss: 0.226229
# [248]	valid_0's multi_logloss: 0.226229
# [249]	valid_0's multi_logloss: 0.226228
# [250]	valid_0's multi_logloss: 0.226229
# [251]	valid_0's multi_logloss: 0.226221
# [252]	valid_0's multi_logloss: 0.226226
# [253]	valid_0's multi_logloss: 0.226221
# [254]	valid_0's multi_logloss: 0.226206
# [255]	valid_0's multi_logloss: 0.2262
# [256]	valid_0's multi_logloss: 0.226188
# [257]	valid_0's multi_logloss: 0.226188
# [258]	valid_0's multi_logloss: 0.226192
# [259]	valid_0's multi_logloss: 0.226183
# [260]	valid_0's multi_logloss: 0.226189
# [261]	valid_0's multi_logloss: 0.226191
# [262]	valid_0's multi_logloss: 0.226198
# [263]	valid_0's multi_logloss: 0.226166
# [264]	valid_0's multi_logloss: 0.226163
# [265]	valid_0's multi_logloss: 0.226162
# [266]	valid_0's multi_logloss: 0.226161
# [267]	valid_0's multi_logloss: 0.226156
# [268]	valid_0's multi_logloss: 0.226152
# [269]	valid_0's multi_logloss: 0.226147
# [270]	valid_0's multi_logloss: 0.226146
# [271]	valid_0's multi_logloss: 0.22614
# [272]	valid_0's multi_logloss: 0.226138
# [273]	valid_0's multi_logloss: 0.226141
# [274]	valid_0's multi_logloss: 0.226139
# [275]	valid_0's multi_logloss: 0.226137
# [276]	valid_0's multi_logloss: 0.226132
# [277]	valid_0's multi_logloss: 0.226128
# [278]	valid_0's multi_logloss: 0.226125
# [279]	valid_0's multi_logloss: 0.226123
# [280]	valid_0's multi_logloss: 0.226124
# [281]	valid_0's multi_logloss: 0.226125
# [282]	valid_0's multi_logloss: 0.22613
# [283]	valid_0's multi_logloss: 0.22613
# [284]	valid_0's multi_logloss: 0.226122
# [285]	valid_0's multi_logloss: 0.226123
# [286]	valid_0's multi_logloss: 0.226125
# [287]	valid_0's multi_logloss: 0.226123
# [288]	valid_0's multi_logloss: 0.226123
# [289]	valid_0's multi_logloss: 0.226116
# [290]	valid_0's multi_logloss: 0.226105
# [291]	valid_0's multi_logloss: 0.226104
# [292]	valid_0's multi_logloss: 0.226108
# [293]	valid_0's multi_logloss: 0.226097
# [294]	valid_0's multi_logloss: 0.226102
# [295]	valid_0's multi_logloss: 0.226103
# [296]	valid_0's multi_logloss: 0.226088
# [297]	valid_0's multi_logloss: 0.226087
# [298]	valid_0's multi_logloss: 0.226085
# [299]	valid_0's multi_logloss: 0.226087
# [300]	valid_0's multi_logloss: 0.226084
# [301]	valid_0's multi_logloss: 0.22607
# [302]	valid_0's multi_logloss: 0.226069
# [303]	valid_0's multi_logloss: 0.22607
# [304]	valid_0's multi_logloss: 0.22607
# [305]	valid_0's multi_logloss: 0.226069
# [306]	valid_0's multi_logloss: 0.226063
# [307]	valid_0's multi_logloss: 0.226063
# [308]	valid_0's multi_logloss: 0.226063
# [309]	valid_0's multi_logloss: 0.226063
# [310]	valid_0's multi_logloss: 0.226062
# [311]	valid_0's multi_logloss: 0.226042
# [312]	valid_0's multi_logloss: 0.226042
# [313]	valid_0's multi_logloss: 0.226043
# [314]	valid_0's multi_logloss: 0.226039
# [315]	valid_0's multi_logloss: 0.226034
# [316]	valid_0's multi_logloss: 0.226033
# [317]	valid_0's multi_logloss: 0.226035
# [318]	valid_0's multi_logloss: 0.226038
# [319]	valid_0's multi_logloss: 0.226041
# [320]	valid_0's multi_logloss: 0.226037
# [321]	valid_0's multi_logloss: 0.226037
# [322]	valid_0's multi_logloss: 0.226034
# [323]	valid_0's multi_logloss: 0.226037
# [324]	valid_0's multi_logloss: 0.226032
# [325]	valid_0's multi_logloss: 0.226031
# [326]	valid_0's multi_logloss: 0.226022
# [327]	valid_0's multi_logloss: 0.226018
# [328]	valid_0's multi_logloss: 0.226021
# [329]	valid_0's multi_logloss: 0.226022
# [330]	valid_0's multi_logloss: 0.226023
# [331]	valid_0's multi_logloss: 0.226016
# [332]	valid_0's multi_logloss: 0.226018
# [333]	valid_0's multi_logloss: 0.226012
# [334]	valid_0's multi_logloss: 0.226009
# [335]	valid_0's multi_logloss: 0.226012
# [336]	valid_0's multi_logloss: 0.226006
# [337]	valid_0's multi_logloss: 0.22601
# [338]	valid_0's multi_logloss: 0.226008
# [339]	valid_0's multi_logloss: 0.22601
# [340]	valid_0's multi_logloss: 0.226004
# [341]	valid_0's multi_logloss: 0.225999
# [342]	valid_0's multi_logloss: 0.226002
# [343]	valid_0's multi_logloss: 0.226005
# [344]	valid_0's multi_logloss: 0.226004
# [345]	valid_0's multi_logloss: 0.225991
# [346]	valid_0's multi_logloss: 0.225994
# [347]	valid_0's multi_logloss: 0.225992
# [348]	valid_0's multi_logloss: 0.225991
# [349]	valid_0's multi_logloss: 0.225994
# [350]	valid_0's multi_logloss: 0.225995
# [351]	valid_0's multi_logloss: 0.225991
# [352]	valid_0's multi_logloss: 0.225991
# [353]	valid_0's multi_logloss: 0.225988
# [354]	valid_0's multi_logloss: 0.22599
# [355]	valid_0's multi_logloss: 0.22599
# [356]	valid_0's multi_logloss: 0.225986
# [357]	valid_0's multi_logloss: 0.22599
# [358]	valid_0's multi_logloss: 0.225985
# [359]	valid_0's multi_logloss: 0.22598
# [360]	valid_0's multi_logloss: 0.225977
# [361]	valid_0's multi_logloss: 0.225973
# [362]	valid_0's multi_logloss: 0.225969
# [363]	valid_0's multi_logloss: 0.225972
# [364]	valid_0's multi_logloss: 0.225969
# [365]	valid_0's multi_logloss: 0.225969
# [366]	valid_0's multi_logloss: 0.225966
# [367]	valid_0's multi_logloss: 0.225972
# [368]	valid_0's multi_logloss: 0.225974
# [369]	valid_0's multi_logloss: 0.225974
# [370]	valid_0's multi_logloss: 0.225975
# [371]	valid_0's multi_logloss: 0.225977
# [372]	valid_0's multi_logloss: 0.225976
# [373]	valid_0's multi_logloss: 0.225972
# [374]	valid_0's multi_logloss: 0.225973
# [375]	valid_0's multi_logloss: 0.225964
# [376]	valid_0's multi_logloss: 0.225966
# [377]	valid_0's multi_logloss: 0.225968
# [378]	valid_0's multi_logloss: 0.225969
# [379]	valid_0's multi_logloss: 0.225964
# [380]	valid_0's multi_logloss: 0.225969
# [381]	valid_0's multi_logloss: 0.225969
# [382]	valid_0's multi_logloss: 0.225967
# [383]	valid_0's multi_logloss: 0.225968
# [384]	valid_0's multi_logloss: 0.225969
# [385]	valid_0's multi_logloss: 0.22597
# [386]	valid_0's multi_logloss: 0.225971
# [387]	valid_0's multi_logloss: 0.22597
# [388]	valid_0's multi_logloss: 0.225966
# [389]	valid_0's multi_logloss: 0.225964
# [390]	valid_0's multi_logloss: 0.225962
# [391]	valid_0's multi_logloss: 0.225962
# [392]	valid_0's multi_logloss: 0.225958
# [393]	valid_0's multi_logloss: 0.225963
# [394]	valid_0's multi_logloss: 0.225963
# [395]	valid_0's multi_logloss: 0.225962
# [396]	valid_0's multi_logloss: 0.225962
# [397]	valid_0's multi_logloss: 0.225966
# [398]	valid_0's multi_logloss: 0.225963
# [399]	valid_0's multi_logloss: 0.225961
# [400]	valid_0's multi_logloss: 0.225961
# [401]	valid_0's multi_logloss: 0.225957
# [402]	valid_0's multi_logloss: 0.225957
# [403]	valid_0's multi_logloss: 0.225957
# [404]	valid_0's multi_logloss: 0.225961
# [405]	valid_0's multi_logloss: 0.225961
# [406]	valid_0's multi_logloss: 0.225964
# [407]	valid_0's multi_logloss: 0.225969
# [408]	valid_0's multi_logloss: 0.22597
# [409]	valid_0's multi_logloss: 0.225967
# [410]	valid_0's multi_logloss: 0.225964
# [411]	valid_0's multi_logloss: 0.22597
# [412]	valid_0's multi_logloss: 0.225971
# [413]	valid_0's multi_logloss: 0.225965
# [414]	valid_0's multi_logloss: 0.225972
# [415]	valid_0's multi_logloss: 0.225975
# [416]	valid_0's multi_logloss: 0.225974
# [417]	valid_0's multi_logloss: 0.225972
# [418]	valid_0's multi_logloss: 0.225971
# [419]	valid_0's multi_logloss: 0.22597
# [420]	valid_0's multi_logloss: 0.22597
# [421]	valid_0's multi_logloss: 0.225965
# [422]	valid_0's multi_logloss: 0.225964
# [423]	valid_0's multi_logloss: 0.225964
# [424]	valid_0's multi_logloss: 0.225964
# [425]	valid_0's multi_logloss: 0.225964
# [426]	valid_0's multi_logloss: 0.225961
# [427]	valid_0's multi_logloss: 0.225967
# [428]	valid_0's multi_logloss: 0.225963
# [429]	valid_0's multi_logloss: 0.225959
# [430]	valid_0's multi_logloss: 0.225955
# [431]	valid_0's multi_logloss: 0.225955
# [432]	valid_0's multi_logloss: 0.225956
# [433]	valid_0's multi_logloss: 0.225937
# [434]	valid_0's multi_logloss: 0.225936
# [435]	valid_0's multi_logloss: 0.225931
# [436]	valid_0's multi_logloss: 0.22593
# [437]	valid_0's multi_logloss: 0.225933
# [438]	valid_0's multi_logloss: 0.225933
# [439]	valid_0's multi_logloss: 0.22594
# [440]	valid_0's multi_logloss: 0.225943
# [441]	valid_0's multi_logloss: 0.225947
# [442]	valid_0's multi_logloss: 0.225943
# [443]	valid_0's multi_logloss: 0.225945
# [444]	valid_0's multi_logloss: 0.225949
# [445]	valid_0's multi_logloss: 0.225934
# [446]	valid_0's multi_logloss: 0.225935
# [447]	valid_0's multi_logloss: 0.225936
# [448]	valid_0's multi_logloss: 0.225937
# [449]	valid_0's multi_logloss: 0.22594
# [450]	valid_0's multi_logloss: 0.225936
# [451]	valid_0's multi_logloss: 0.225933
# [452]	valid_0's multi_logloss: 0.225932
# [453]	valid_0's multi_logloss: 0.225935
# [454]	valid_0's multi_logloss: 0.225935
# [455]	valid_0's multi_logloss: 0.225933
# [456]	valid_0's multi_logloss: 0.225933
# [457]	valid_0's multi_logloss: 0.225932
# [458]	valid_0's multi_logloss: 0.225936
# [459]	valid_0's multi_logloss: 0.22593
# [460]	valid_0's multi_logloss: 0.225929
# [461]	valid_0's multi_logloss: 0.22593
# [462]	valid_0's multi_logloss: 0.225909
# [463]	valid_0's multi_logloss: 0.225903
# [464]	valid_0's multi_logloss: 0.225898
# [465]	valid_0's multi_logloss: 0.225899
# [466]	valid_0's multi_logloss: 0.225901
# [467]	valid_0's multi_logloss: 0.225901
# [468]	valid_0's multi_logloss: 0.225901
# [469]	valid_0's multi_logloss: 0.225901
# [470]	valid_0's multi_logloss: 0.225903
# [471]	valid_0's multi_logloss: 0.225903
# [472]	valid_0's multi_logloss: 0.225903
# [473]	valid_0's multi_logloss: 0.225898
# [474]	valid_0's multi_logloss: 0.225902
# [475]	valid_0's multi_logloss: 0.225903
# [476]	valid_0's multi_logloss: 0.225901
# [477]	valid_0's multi_logloss: 0.225902
# [478]	valid_0's multi_logloss: 0.225905
# [479]	valid_0's multi_logloss: 0.225906
# [480]	valid_0's multi_logloss: 0.225901
# [481]	valid_0's multi_logloss: 0.225898
# [482]	valid_0's multi_logloss: 0.225892
# [483]	valid_0's multi_logloss: 0.225883
# [484]	valid_0's multi_logloss: 0.225888
# [485]	valid_0's multi_logloss: 0.225888
# [486]	valid_0's multi_logloss: 0.225891
# [487]	valid_0's multi_logloss: 0.225873
# [488]	valid_0's multi_logloss: 0.225868
# [489]	valid_0's multi_logloss: 0.225874
# [490]	valid_0's multi_logloss: 0.225874
# [491]	valid_0's multi_logloss: 0.225877
# [492]	valid_0's multi_logloss: 0.225878
# [493]	valid_0's multi_logloss: 0.225876
# [494]	valid_0's multi_logloss: 0.225875
# [495]	valid_0's multi_logloss: 0.225872
# [496]	valid_0's multi_logloss: 0.225871
# [497]	valid_0's multi_logloss: 0.225872
# [498]	valid_0's multi_logloss: 0.225874
# [499]	valid_0's multi_logloss: 0.225871
# [500]	valid_0's multi_logloss: 0.225875
# [501]	valid_0's multi_logloss: 0.225874
# [502]	valid_0's multi_logloss: 0.225875
# [503]	valid_0's multi_logloss: 0.225876
# [504]	valid_0's multi_logloss: 0.225876
# [505]	valid_0's multi_logloss: 0.225872
# [506]	valid_0's multi_logloss: 0.225861
# [507]	valid_0's multi_logloss: 0.225866
# [508]	valid_0's multi_logloss: 0.225859
# [509]	valid_0's multi_logloss: 0.22586
# [510]	valid_0's multi_logloss: 0.225846
# [511]	valid_0's multi_logloss: 0.225839
# [512]	valid_0's multi_logloss: 0.22584
# [513]	valid_0's multi_logloss: 0.225837
# [514]	valid_0's multi_logloss: 0.225842
# [515]	valid_0's multi_logloss: 0.225847
# [516]	valid_0's multi_logloss: 0.225848
# [517]	valid_0's multi_logloss: 0.225849
# [518]	valid_0's multi_logloss: 0.225845
# [519]	valid_0's multi_logloss: 0.225838
# [520]	valid_0's multi_logloss: 0.225838
# [521]	valid_0's multi_logloss: 0.225833
# [522]	valid_0's multi_logloss: 0.225833
# [523]	valid_0's multi_logloss: 0.225826
# [524]	valid_0's multi_logloss: 0.225827
# [525]	valid_0's multi_logloss: 0.225827
# [526]	valid_0's multi_logloss: 0.225829
# [527]	valid_0's multi_logloss: 0.225813
# [528]	valid_0's multi_logloss: 0.225814
# [529]	valid_0's multi_logloss: 0.225812
# [530]	valid_0's multi_logloss: 0.225807
# [531]	valid_0's multi_logloss: 0.225809
# [532]	valid_0's multi_logloss: 0.225812
# [533]	valid_0's multi_logloss: 0.225813
# [534]	valid_0's multi_logloss: 0.225813
# [535]	valid_0's multi_logloss: 0.225813
# [536]	valid_0's multi_logloss: 0.225815
# [537]	valid_0's multi_logloss: 0.225812
# [538]	valid_0's multi_logloss: 0.225812
# [539]	valid_0's multi_logloss: 0.225813
# [540]	valid_0's multi_logloss: 0.225814
# [541]	valid_0's multi_logloss: 0.225813
# [542]	valid_0's multi_logloss: 0.225815
# [543]	valid_0's multi_logloss: 0.225816
# [544]	valid_0's multi_logloss: 0.225815
# [545]	valid_0's multi_logloss: 0.225819
# [546]	valid_0's multi_logloss: 0.22582
# [547]	valid_0's multi_logloss: 0.22582
# [548]	valid_0's multi_logloss: 0.225821
# [549]	valid_0's multi_logloss: 0.225823
# [550]	valid_0's multi_logloss: 0.22582
# [551]	valid_0's multi_logloss: 0.22582
# [552]	valid_0's multi_logloss: 0.225815
# [553]	valid_0's multi_logloss: 0.225817
# [554]	valid_0's multi_logloss: 0.225818
# [555]	valid_0's multi_logloss: 0.225819
# [556]	valid_0's multi_logloss: 0.22582
# [557]	valid_0's multi_logloss: 0.225821
# [558]	valid_0's multi_logloss: 0.225821
# [559]	valid_0's multi_logloss: 0.225822
# [560]	valid_0's multi_logloss: 0.225823
# [561]	valid_0's multi_logloss: 0.225826
# [562]	valid_0's multi_logloss: 0.225828
# [563]	valid_0's multi_logloss: 0.225819
# [564]	valid_0's multi_logloss: 0.225817
# [565]	valid_0's multi_logloss: 0.22582
# [566]	valid_0's multi_logloss: 0.225822
# [567]	valid_0's multi_logloss: 0.225823
# [568]	valid_0's multi_logloss: 0.225826
# [569]	valid_0's multi_logloss: 0.225826
# [570]	valid_0's multi_logloss: 0.225824
# [571]	valid_0's multi_logloss: 0.225824
# [572]	valid_0's multi_logloss: 0.225823
# [573]	valid_0's multi_logloss: 0.225823
# [574]	valid_0's multi_logloss: 0.225822
# [575]	valid_0's multi_logloss: 0.225821
# [576]	valid_0's multi_logloss: 0.225826
# [577]	valid_0's multi_logloss: 0.225825
# [578]	valid_0's multi_logloss: 0.225824
# [579]	valid_0's multi_logloss: 0.225831
# [580]	valid_0's multi_logloss: 0.225832
# [581]	valid_0's multi_logloss: 0.225833
# [582]	valid_0's multi_logloss: 0.225829
# [583]	valid_0's multi_logloss: 0.225819
# [584]	valid_0's multi_logloss: 0.225817
# [585]	valid_0's multi_logloss: 0.225817
# [586]	valid_0's multi_logloss: 0.225817
# [587]	valid_0's multi_logloss: 0.22582
# [588]	valid_0's multi_logloss: 0.225823
# [589]	valid_0's multi_logloss: 0.225824
# [590]	valid_0's multi_logloss: 0.225823
# [591]	valid_0's multi_logloss: 0.225819
# [592]	valid_0's multi_logloss: 0.225814
# [593]	valid_0's multi_logloss: 0.225812
# [594]	valid_0's multi_logloss: 0.225807
# [595]	valid_0's multi_logloss: 0.225806
# [596]	valid_0's multi_logloss: 0.225811
# [597]	valid_0's multi_logloss: 0.225811
# [598]	valid_0's multi_logloss: 0.225812
# [599]	valid_0's multi_logloss: 0.22581
# [600]	valid_0's multi_logloss: 0.225814
# [601]	valid_0's multi_logloss: 0.225812
# [602]	valid_0's multi_logloss: 0.225814
# [603]	valid_0's multi_logloss: 0.22582
# [604]	valid_0's multi_logloss: 0.225809
# [605]	valid_0's multi_logloss: 0.225813
# [606]	valid_0's multi_logloss: 0.225808
# [607]	valid_0's multi_logloss: 0.225804
# [608]	valid_0's multi_logloss: 0.225798
# [609]	valid_0's multi_logloss: 0.225798
# [610]	valid_0's multi_logloss: 0.225799
# [611]	valid_0's multi_logloss: 0.225797
# [612]	valid_0's multi_logloss: 0.225792
# [613]	valid_0's multi_logloss: 0.225798
# [614]	valid_0's multi_logloss: 0.225801
# [615]	valid_0's multi_logloss: 0.225791
# [616]	valid_0's multi_logloss: 0.225794
# [617]	valid_0's multi_logloss: 0.225799
# [618]	valid_0's multi_logloss: 0.225804
# [619]	valid_0's multi_logloss: 0.225794
# [620]	valid_0's multi_logloss: 0.225795
# [621]	valid_0's multi_logloss: 0.225795
# [622]	valid_0's multi_logloss: 0.225793
# [623]	valid_0's multi_logloss: 0.225787
# [624]	valid_0's multi_logloss: 0.225788
# [625]	valid_0's multi_logloss: 0.22579
# [626]	valid_0's multi_logloss: 0.225791
# [627]	valid_0's multi_logloss: 0.225779
# [628]	valid_0's multi_logloss: 0.225782
# [629]	valid_0's multi_logloss: 0.225775
# [630]	valid_0's multi_logloss: 0.225775
# [631]	valid_0's multi_logloss: 0.225778
# [632]	valid_0's multi_logloss: 0.225778
# [633]	valid_0's multi_logloss: 0.225773
# [634]	valid_0's multi_logloss: 0.225774
# [635]	valid_0's multi_logloss: 0.225774
# [636]	valid_0's multi_logloss: 0.225774
# [637]	valid_0's multi_logloss: 0.225772
# [638]	valid_0's multi_logloss: 0.225774
# [639]	valid_0's multi_logloss: 0.225775
# [640]	valid_0's multi_logloss: 0.225776
# [641]	valid_0's multi_logloss: 0.225776
# [642]	valid_0's multi_logloss: 0.225777
# [643]	valid_0's multi_logloss: 0.225775
# [644]	valid_0's multi_logloss: 0.225782
# [645]	valid_0's multi_logloss: 0.225781
# [646]	valid_0's multi_logloss: 0.225784
# [647]	valid_0's multi_logloss: 0.225784
# [648]	valid_0's multi_logloss: 0.225785
# [649]	valid_0's multi_logloss: 0.225783
# [650]	valid_0's multi_logloss: 0.225782
# [651]	valid_0's multi_logloss: 0.225778
# [652]	valid_0's multi_logloss: 0.225781
# [653]	valid_0's multi_logloss: 0.225788
# [654]	valid_0's multi_logloss: 0.225796
# [655]	valid_0's multi_logloss: 0.225799
# [656]	valid_0's multi_logloss: 0.225801
# [657]	valid_0's multi_logloss: 0.225798
# [658]	valid_0's multi_logloss: 0.225794
# [659]	valid_0's multi_logloss: 0.225794
# [660]	valid_0's multi_logloss: 0.225791
# [661]	valid_0's multi_logloss: 0.225794
# [662]	valid_0's multi_logloss: 0.225801
# [663]	valid_0's multi_logloss: 0.225802
# [664]	valid_0's multi_logloss: 0.225802
# [665]	valid_0's multi_logloss: 0.225792
# [666]	valid_0's multi_logloss: 0.225793
# [667]	valid_0's multi_logloss: 0.225788
# [668]	valid_0's multi_logloss: 0.225793
# [669]	valid_0's multi_logloss: 0.225793
# [670]	valid_0's multi_logloss: 0.22579
# [671]	valid_0's multi_logloss: 0.225788
# [672]	valid_0's multi_logloss: 0.225785
# [673]	valid_0's multi_logloss: 0.225776
# [674]	valid_0's multi_logloss: 0.225776
# [675]	valid_0's multi_logloss: 0.225776
# [676]	valid_0's multi_logloss: 0.225776
# [677]	valid_0's multi_logloss: 0.225775
# [678]	valid_0's multi_logloss: 0.22577
# [679]	valid_0's multi_logloss: 0.225768
# [680]	valid_0's multi_logloss: 0.225772
# [681]	valid_0's multi_logloss: 0.225771
# [682]	valid_0's multi_logloss: 0.225773
# [683]	valid_0's multi_logloss: 0.225773
# [684]	valid_0's multi_logloss: 0.225782
# [685]	valid_0's multi_logloss: 0.22578
# [686]	valid_0's multi_logloss: 0.225779
# [687]	valid_0's multi_logloss: 0.225776
# [688]	valid_0's multi_logloss: 0.225775
# [689]	valid_0's multi_logloss: 0.225774
# [690]	valid_0's multi_logloss: 0.225778
# [691]	valid_0's multi_logloss: 0.225778
# [692]	valid_0's multi_logloss: 0.225775
# [693]	valid_0's multi_logloss: 0.225773
# [694]	valid_0's multi_logloss: 0.225769
# [695]	valid_0's multi_logloss: 0.225768
# ...
# [102]	valid_0's multi_logloss: 0.224657
# [103]	valid_0's multi_logloss: 0.224646
# [104]	valid_0's multi_logloss: 0.224632
# [105]	valid_0's multi_logloss: 0.224621
# [106]	valid_0's multi_logloss: 0.224621
# [107]	valid_0's multi_logloss: 0.224613
# [108]	valid_0's multi_logloss: 0.224596
# [109]	valid_0's multi_logloss: 0.22458
# [110]	valid_0's multi_logloss: 0.224569
# [111]	valid_0's multi_logloss: 0.22456
# [112]	valid_0's multi_logloss: 0.224554
# [113]	valid_0's multi_logloss: 0.224541
# [114]	valid_0's multi_logloss: 0.224528
# [115]	valid_0's multi_logloss: 0.224512
# [116]	valid_0's multi_logloss: 0.224506
# [117]	valid_0's multi_logloss: 0.224493
# [118]	valid_0's multi_logloss: 0.224474
# [119]	valid_0's multi_logloss: 0.224458
# [120]	valid_0's multi_logloss: 0.224458
# [121]	valid_0's multi_logloss: 0.224446
# [122]	valid_0's multi_logloss: 0.224442
# [123]	valid_0's multi_logloss: 0.224441
# [124]	valid_0's multi_logloss: 0.224442
# [125]	valid_0's multi_logloss: 0.22443
# [126]	valid_0's multi_logloss: 0.224424
# [127]	valid_0's multi_logloss: 0.224415
# [128]	valid_0's multi_logloss: 0.224414
# [129]	valid_0's multi_logloss: 0.224409
# [130]	valid_0's multi_logloss: 0.224405
# [131]	valid_0's multi_logloss: 0.224398
# [132]	valid_0's multi_logloss: 0.224389
# [133]	valid_0's multi_logloss: 0.224393
# [134]	valid_0's multi_logloss: 0.22439
# [135]	valid_0's multi_logloss: 0.224382
# [136]	valid_0's multi_logloss: 0.22438
# [137]	valid_0's multi_logloss: 0.224379
# [138]	valid_0's multi_logloss: 0.224365
# [139]	valid_0's multi_logloss: 0.224349
# [140]	valid_0's multi_logloss: 0.224337
# [141]	valid_0's multi_logloss: 0.224332
# [142]	valid_0's multi_logloss: 0.224328
# [143]	valid_0's multi_logloss: 0.224331
# [144]	valid_0's multi_logloss: 0.224327
# [145]	valid_0's multi_logloss: 0.224311
# [146]	valid_0's multi_logloss: 0.224309
# [147]	valid_0's multi_logloss: 0.224302
# [148]	valid_0's multi_logloss: 0.224304
# [149]	valid_0's multi_logloss: 0.224296
# [150]	valid_0's multi_logloss: 0.224289
# [151]	valid_0's multi_logloss: 0.224291
# [152]	valid_0's multi_logloss: 0.224293
# [153]	valid_0's multi_logloss: 0.224292
# [154]	valid_0's multi_logloss: 0.224271
# [155]	valid_0's multi_logloss: 0.224263
# [156]	valid_0's multi_logloss: 0.224261
# [157]	valid_0's multi_logloss: 0.224251
# [158]	valid_0's multi_logloss: 0.224218
# [159]	valid_0's multi_logloss: 0.224207
# [160]	valid_0's multi_logloss: 0.224205
# [161]	valid_0's multi_logloss: 0.224202
# [162]	valid_0's multi_logloss: 0.224193
# [163]	valid_0's multi_logloss: 0.224184
# [164]	valid_0's multi_logloss: 0.224181
# [165]	valid_0's multi_logloss: 0.22418
# [166]	valid_0's multi_logloss: 0.224174
# [167]	valid_0's multi_logloss: 0.224169
# [168]	valid_0's multi_logloss: 0.224161
# [169]	valid_0's multi_logloss: 0.22416
# [170]	valid_0's multi_logloss: 0.22416
# [171]	valid_0's multi_logloss: 0.224162
# [172]	valid_0's multi_logloss: 0.224157
# [173]	valid_0's multi_logloss: 0.224154
# [174]	valid_0's multi_logloss: 0.224156
# [175]	valid_0's multi_logloss: 0.224143
# [176]	valid_0's multi_logloss: 0.224143
# [177]	valid_0's multi_logloss: 0.224141
# [178]	valid_0's multi_logloss: 0.224133
# [179]	valid_0's multi_logloss: 0.224131
# [180]	valid_0's multi_logloss: 0.224122
# [181]	valid_0's multi_logloss: 0.224111
# [182]	valid_0's multi_logloss: 0.224109
# [183]	valid_0's multi_logloss: 0.224099
# [184]	valid_0's multi_logloss: 0.224095
# [185]	valid_0's multi_logloss: 0.224091
# [186]	valid_0's multi_logloss: 0.224091
# [187]	valid_0's multi_logloss: 0.224092
# [188]	valid_0's multi_logloss: 0.224099
# [189]	valid_0's multi_logloss: 0.224091
# [190]	valid_0's multi_logloss: 0.22409
# [191]	valid_0's multi_logloss: 0.224082
# [192]	valid_0's multi_logloss: 0.224078
# [193]	valid_0's multi_logloss: 0.224079
# [194]	valid_0's multi_logloss: 0.224082
# [195]	valid_0's multi_logloss: 0.224068
# [196]	valid_0's multi_logloss: 0.224063
# [197]	valid_0's multi_logloss: 0.224059
# [198]	valid_0's multi_logloss: 0.224059
# [199]	valid_0's multi_logloss: 0.224062
# [200]	valid_0's multi_logloss: 0.224063
# [201]	valid_0's multi_logloss: 0.224057
# [202]	valid_0's multi_logloss: 0.22405
# [203]	valid_0's multi_logloss: 0.224055
# [204]	valid_0's multi_logloss: 0.224058
# [205]	valid_0's multi_logloss: 0.224061
# [206]	valid_0's multi_logloss: 0.224065
# [207]	valid_0's multi_logloss: 0.22407
# [208]	valid_0's multi_logloss: 0.224063
# [209]	valid_0's multi_logloss: 0.224063
# [210]	valid_0's multi_logloss: 0.224066
# [211]	valid_0's multi_logloss: 0.224055
# [212]	valid_0's multi_logloss: 0.224052
# [213]	valid_0's multi_logloss: 0.224055
# [214]	valid_0's multi_logloss: 0.224053
# [215]	valid_0's multi_logloss: 0.224054
# [216]	valid_0's multi_logloss: 0.224054
# [217]	valid_0's multi_logloss: 0.224055
# [218]	valid_0's multi_logloss: 0.224039
# [219]	valid_0's multi_logloss: 0.224042
# [220]	valid_0's multi_logloss: 0.224041
# [221]	valid_0's multi_logloss: 0.22403
# [222]	valid_0's multi_logloss: 0.223974
# [223]	valid_0's multi_logloss: 0.223962
# [224]	valid_0's multi_logloss: 0.22396
# [225]	valid_0's multi_logloss: 0.223956
# [226]	valid_0's multi_logloss: 0.223956
# [227]	valid_0's multi_logloss: 0.223955
# [228]	valid_0's multi_logloss: 0.223959
# [229]	valid_0's multi_logloss: 0.223959
# [230]	valid_0's multi_logloss: 0.22396
# [231]	valid_0's multi_logloss: 0.223961
# [232]	valid_0's multi_logloss: 0.223956
# [233]	valid_0's multi_logloss: 0.223958
# [234]	valid_0's multi_logloss: 0.22396
# [235]	valid_0's multi_logloss: 0.223959
# [236]	valid_0's multi_logloss: 0.223955
# [237]	valid_0's multi_logloss: 0.223949
# [238]	valid_0's multi_logloss: 0.223951
# [239]	valid_0's multi_logloss: 0.223941
# [240]	valid_0's multi_logloss: 0.223944
# [241]	valid_0's multi_logloss: 0.223943
# [242]	valid_0's multi_logloss: 0.223951
# [243]	valid_0's multi_logloss: 0.223948
# [244]	valid_0's multi_logloss: 0.223941
# [245]	valid_0's multi_logloss: 0.223941
# [246]	valid_0's multi_logloss: 0.223936
# [247]	valid_0's multi_logloss: 0.223924
# [248]	valid_0's multi_logloss: 0.223922
# [249]	valid_0's multi_logloss: 0.22393
# [250]	valid_0's multi_logloss: 0.223933
# [251]	valid_0's multi_logloss: 0.223925
# [252]	valid_0's multi_logloss: 0.223921
# [253]	valid_0's multi_logloss: 0.223925
# [254]	valid_0's multi_logloss: 0.223926
# [255]	valid_0's multi_logloss: 0.223931
# [256]	valid_0's multi_logloss: 0.223929
# [257]	valid_0's multi_logloss: 0.223926
# [258]	valid_0's multi_logloss: 0.223929
# [259]	valid_0's multi_logloss: 0.223929
# [260]	valid_0's multi_logloss: 0.223934
# [261]	valid_0's multi_logloss: 0.22393
# [262]	valid_0's multi_logloss: 0.223924
# [263]	valid_0's multi_logloss: 0.223917
# [264]	valid_0's multi_logloss: 0.223913
# [265]	valid_0's multi_logloss: 0.223914
# [266]	valid_0's multi_logloss: 0.223916
# [267]	valid_0's multi_logloss: 0.223912
# [268]	valid_0's multi_logloss: 0.223908
# [269]	valid_0's multi_logloss: 0.223901
# [270]	valid_0's multi_logloss: 0.2239
# [271]	valid_0's multi_logloss: 0.223901
# [272]	valid_0's multi_logloss: 0.223901
# [273]	valid_0's multi_logloss: 0.223901
# [274]	valid_0's multi_logloss: 0.223905
# [275]	valid_0's multi_logloss: 0.223904
# [276]	valid_0's multi_logloss: 0.223905
# [277]	valid_0's multi_logloss: 0.223907
# [278]	valid_0's multi_logloss: 0.223899
# [279]	valid_0's multi_logloss: 0.223895
# [280]	valid_0's multi_logloss: 0.223898
# [281]	valid_0's multi_logloss: 0.223906
# [282]	valid_0's multi_logloss: 0.223911
# [283]	valid_0's multi_logloss: 0.223913
# [284]	valid_0's multi_logloss: 0.22391
# [285]	valid_0's multi_logloss: 0.223912
# [286]	valid_0's multi_logloss: 0.223913
# [287]	valid_0's multi_logloss: 0.223911
# [288]	valid_0's multi_logloss: 0.22391
# [289]	valid_0's multi_logloss: 0.223906
# [290]	valid_0's multi_logloss: 0.22391
# [291]	valid_0's multi_logloss: 0.223906
# [292]	valid_0's multi_logloss: 0.223888
# [293]	valid_0's multi_logloss: 0.223886
# [294]	valid_0's multi_logloss: 0.223887
# [295]	valid_0's multi_logloss: 0.22389
# [296]	valid_0's multi_logloss: 0.223887
# [297]	valid_0's multi_logloss: 0.223882
# [298]	valid_0's multi_logloss: 0.223883
# [299]	valid_0's multi_logloss: 0.223878
# [300]	valid_0's multi_logloss: 0.223873
# [301]	valid_0's multi_logloss: 0.223876
# [302]	valid_0's multi_logloss: 0.223877
# [303]	valid_0's multi_logloss: 0.223871
# [304]	valid_0's multi_logloss: 0.223872
# [305]	valid_0's multi_logloss: 0.223875
# [306]	valid_0's multi_logloss: 0.223874
# [307]	valid_0's multi_logloss: 0.223872
# [308]	valid_0's multi_logloss: 0.223872
# [309]	valid_0's multi_logloss: 0.223878
# [310]	valid_0's multi_logloss: 0.223884
# [311]	valid_0's multi_logloss: 0.223885
# [312]	valid_0's multi_logloss: 0.223883
# [313]	valid_0's multi_logloss: 0.223881
# [314]	valid_0's multi_logloss: 0.223883
# [315]	valid_0's multi_logloss: 0.223885
# [316]	valid_0's multi_logloss: 0.223884
# [317]	valid_0's multi_logloss: 0.223884
# [318]	valid_0's multi_logloss: 0.223879
# [319]	valid_0's multi_logloss: 0.223877
# [320]	valid_0's multi_logloss: 0.223878
# [321]	valid_0's multi_logloss: 0.223877
# [322]	valid_0's multi_logloss: 0.223878
# [323]	valid_0's multi_logloss: 0.223882
# [324]	valid_0's multi_logloss: 0.223877
# [325]	valid_0's multi_logloss: 0.223879
# [326]	valid_0's multi_logloss: 0.223877
# [327]	valid_0's multi_logloss: 0.223877
# [328]	valid_0's multi_logloss: 0.223873
# [329]	valid_0's multi_logloss: 0.223871
# [330]	valid_0's multi_logloss: 0.223875
# [331]	valid_0's multi_logloss: 0.223868
# [332]	valid_0's multi_logloss: 0.223869
# [333]	valid_0's multi_logloss: 0.223869
# [334]	valid_0's multi_logloss: 0.223872
# [335]	valid_0's multi_logloss: 0.223871
# [336]	valid_0's multi_logloss: 0.22386
# [337]	valid_0's multi_logloss: 0.223865
# [338]	valid_0's multi_logloss: 0.223862
# [339]	valid_0's multi_logloss: 0.223862
# [340]	valid_0's multi_logloss: 0.223863
# [341]	valid_0's multi_logloss: 0.223864
# [342]	valid_0's multi_logloss: 0.223866
# [343]	valid_0's multi_logloss: 0.223866
# [344]	valid_0's multi_logloss: 0.223869
# [345]	valid_0's multi_logloss: 0.223872
# [346]	valid_0's multi_logloss: 0.22387
# [347]	valid_0's multi_logloss: 0.223872
# [348]	valid_0's multi_logloss: 0.223873
# [349]	valid_0's multi_logloss: 0.223875
# [350]	valid_0's multi_logloss: 0.22388
# [351]	valid_0's multi_logloss: 0.223878
# [352]	valid_0's multi_logloss: 0.22388
# [353]	valid_0's multi_logloss: 0.223883
# [354]	valid_0's multi_logloss: 0.223886
# [355]	valid_0's multi_logloss: 0.22389
# [356]	valid_0's multi_logloss: 0.223885
# [357]	valid_0's multi_logloss: 0.223884
# [358]	valid_0's multi_logloss: 0.223886
# [359]	valid_0's multi_logloss: 0.223887
# [360]	valid_0's multi_logloss: 0.223895
# [361]	valid_0's multi_logloss: 0.223891
# [362]	valid_0's multi_logloss: 0.223887
# [363]	valid_0's multi_logloss: 0.22389
# [364]	valid_0's multi_logloss: 0.223885
# [365]	valid_0's multi_logloss: 0.223883
# [366]	valid_0's multi_logloss: 0.223884
# [367]	valid_0's multi_logloss: 0.223884
# [368]	valid_0's multi_logloss: 0.223886
# [369]	valid_0's multi_logloss: 0.223881
# [370]	valid_0's multi_logloss: 0.223883
# [371]	valid_0's multi_logloss: 0.223886
# [372]	valid_0's multi_logloss: 0.223882
# [373]	valid_0's multi_logloss: 0.223878
# [374]	valid_0's multi_logloss: 0.223868
# [375]	valid_0's multi_logloss: 0.223866
# [376]	valid_0's multi_logloss: 0.223865
# [377]	valid_0's multi_logloss: 0.223859
# [378]	valid_0's multi_logloss: 0.223861
# [379]	valid_0's multi_logloss: 0.22386
# [380]	valid_0's multi_logloss: 0.223863
# [381]	valid_0's multi_logloss: 0.223866
# [382]	valid_0's multi_logloss: 0.223864
# [383]	valid_0's multi_logloss: 0.223858
# [384]	valid_0's multi_logloss: 0.223859
# [385]	valid_0's multi_logloss: 0.223862
# [386]	valid_0's multi_logloss: 0.223862
# [387]	valid_0's multi_logloss: 0.223839
# [388]	valid_0's multi_logloss: 0.223835
# [389]	valid_0's multi_logloss: 0.223834
# [390]	valid_0's multi_logloss: 0.223831
# [391]	valid_0's multi_logloss: 0.223834
# [392]	valid_0's multi_logloss: 0.223831
# [393]	valid_0's multi_logloss: 0.223827
# [394]	valid_0's multi_logloss: 0.223831
# [395]	valid_0's multi_logloss: 0.223829
# [396]	valid_0's multi_logloss: 0.223833
# [397]	valid_0's multi_logloss: 0.22384
# [398]	valid_0's multi_logloss: 0.223842
# [399]	valid_0's multi_logloss: 0.223842
# [400]	valid_0's multi_logloss: 0.223841
# [401]	valid_0's multi_logloss: 0.223849
# [402]	valid_0's multi_logloss: 0.223853
# [403]	valid_0's multi_logloss: 0.223853
# [404]	valid_0's multi_logloss: 0.223855
# [405]	valid_0's multi_logloss: 0.223854
# [406]	valid_0's multi_logloss: 0.223855
# [407]	valid_0's multi_logloss: 0.223858
# [408]	valid_0's multi_logloss: 0.223859
# [409]	valid_0's multi_logloss: 0.22386
# [410]	valid_0's multi_logloss: 0.223861
# [411]	valid_0's multi_logloss: 0.223865
# [412]	valid_0's multi_logloss: 0.223869
# [413]	valid_0's multi_logloss: 0.223868
# [414]	valid_0's multi_logloss: 0.223869
# [415]	valid_0's multi_logloss: 0.22387
# [416]	valid_0's multi_logloss: 0.223869
# [417]	valid_0's multi_logloss: 0.223869
# [418]	valid_0's multi_logloss: 0.223867
# [419]	valid_0's multi_logloss: 0.223862
# [420]	valid_0's multi_logloss: 0.223864
# [421]	valid_0's multi_logloss: 0.223861
# [422]	valid_0's multi_logloss: 0.22386
# [423]	valid_0's multi_logloss: 0.223861
# [424]	valid_0's multi_logloss: 0.223862
# [425]	valid_0's multi_logloss: 0.22386
# [426]	valid_0's multi_logloss: 0.223866
# [427]	valid_0's multi_logloss: 0.223867
# [428]	valid_0's multi_logloss: 0.223866
# [429]	valid_0's multi_logloss: 0.223866
# [430]	valid_0's multi_logloss: 0.223867
# [431]	valid_0's multi_logloss: 0.223866
# [432]	valid_0's multi_logloss: 0.223865
# [433]	valid_0's multi_logloss: 0.223864
# [434]	valid_0's multi_logloss: 0.223862
# [435]	valid_0's multi_logloss: 0.223864
# [436]	valid_0's multi_logloss: 0.223866
# [437]	valid_0's multi_logloss: 0.223868
# [438]	valid_0's multi_logloss: 0.223867
# [439]	valid_0's multi_logloss: 0.223871
# [440]	valid_0's multi_logloss: 0.22387
# [441]	valid_0's multi_logloss: 0.223869
# [442]	valid_0's multi_logloss: 0.223846
# [443]	valid_0's multi_logloss: 0.223848
# [444]	valid_0's multi_logloss: 0.223851
# [445]	valid_0's multi_logloss: 0.223848
# [446]	valid_0's multi_logloss: 0.223829
# [447]	valid_0's multi_logloss: 0.223831
# [448]	valid_0's multi_logloss: 0.223831
# [449]	valid_0's multi_logloss: 0.223831
# [450]	valid_0's multi_logloss: 0.223838
# [451]	valid_0's multi_logloss: 0.223843
# [452]	valid_0's multi_logloss: 0.223843
# [453]	valid_0's multi_logloss: 0.223841
# [454]	valid_0's multi_logloss: 0.223836
# [455]	valid_0's multi_logloss: 0.223842
# [456]	valid_0's multi_logloss: 0.22384
# [457]	valid_0's multi_logloss: 0.22384
# [458]	valid_0's multi_logloss: 0.223847
# [459]	valid_0's multi_logloss: 0.223849
# [460]	valid_0's multi_logloss: 0.223843
# [461]	valid_0's multi_logloss: 0.223847
# [462]	valid_0's multi_logloss: 0.223846
# [463]	valid_0's multi_logloss: 0.223843
# [464]	valid_0's multi_logloss: 0.223844
# [465]	valid_0's multi_logloss: 0.223846
# [466]	valid_0's multi_logloss: 0.223845
# [467]	valid_0's multi_logloss: 0.223845
# [468]	valid_0's multi_logloss: 0.223849
# [469]	valid_0's multi_logloss: 0.223853
# [470]	valid_0's multi_logloss: 0.223851
# [471]	valid_0's multi_logloss: 0.223847
# [472]	valid_0's multi_logloss: 0.223849
# [473]	valid_0's multi_logloss: 0.223848
# [474]	valid_0's multi_logloss: 0.223844
# [475]	valid_0's multi_logloss: 0.223847
# [476]	valid_0's multi_logloss: 0.223851
# [477]	valid_0's multi_logloss: 0.223847
# [478]	valid_0's multi_logloss: 0.223848
# [479]	valid_0's multi_logloss: 0.22385
# [480]	valid_0's multi_logloss: 0.223849
# [481]	valid_0's multi_logloss: 0.223854
# [482]	valid_0's multi_logloss: 0.223855
# [483]	valid_0's multi_logloss: 0.223855
# [484]	valid_0's multi_logloss: 0.223856
# [485]	valid_0's multi_logloss: 0.223859
# [486]	valid_0's multi_logloss: 0.223858
# [487]	valid_0's multi_logloss: 0.223861
# [488]	valid_0's multi_logloss: 0.223862
# [489]	valid_0's multi_logloss: 0.223862
# [490]	valid_0's multi_logloss: 0.223863
# [491]	valid_0's multi_logloss: 0.223862
# [492]	valid_0's multi_logloss: 0.223862
# [493]	valid_0's multi_logloss: 0.223867
# Early stopping, best iteration is:
# [393]	valid_0's multi_logloss: 0.223827
# lgb now score is: [2.702851928277892, 2.726210176961833, 2.719059991490212, 2.707412395515868, 2.7039581955431973]
# lgb_score_list: [2.702851928277892, 2.726210176961833, 2.719059991490212, 2.707412395515868, 2.7039581955431973]
# lgb_score_mean: 2.7118985375578006

# %%
train_stacking = np.concatenate(train_data_list, axis=1)
test_stacking = np.concatenate(test_data_list, axis=1)

# %% [markdown]
# ### 原始特征和stacking特征合并

# %%
# # 合并所有特征
train = pd.DataFrame(np.concatenate([x_train, train_stacking], axis=1))
test = pd.DataFrame(np.concatenate([x_valid, test_stacking], axis=1))

# %% [markdown]
# ### 特征重命名

# %%
df_train_all = pd.DataFrame(train)
df_train_all.columns = features_columns + clf_list_col
df_test_all = pd.DataFrame(test)
df_test_all.columns = features_columns + clf_list_col

# %% [markdown]
# ## ID,LABEL

# %%
df_train_all['user_id'] = all_data_test[~all_data_test['label'].isna()]['user_id']
df_test_all['user_id'] = all_data_test[all_data_test['label'].isna()]['user_id'].values
df_train_all['label'] = all_data_test[~all_data_test['label'].isna()]['label']

# %% [markdown]
# ## train和test保存

# %%
df_train_all.to_csv('train_all.csv',header=True,index=False)
df_test_all.to_csv('test_all.csv',header=True,index=False)
